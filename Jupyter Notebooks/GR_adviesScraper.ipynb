# %% [markdown]
# # GR_AdviesScraper
#
# Doel: GR adviezen uitgebracht vanaf 2019 tot en met 2024 verzamelen.
#
# Toepassing: Bachelor-scriptie Informatiekunde, Universiteit van Amsterdam
#
# Contact: mitchell.malaihollo@student.uva.nl
#
# Metadata Formatering volgens de [Woogle metadata specificatie](https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema)

# %%
import time
from urllib.parse import urljoin
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from openai import OpenAI
from dotenv import load_dotenv
import json
from selenium.common.exceptions import NoSuchElementException
from urllib.parse import urljoin, urlparse
import re

# %%
HREF_ID_WOORDEN = {"briefadvies", "wetsadvies", "advies", "adviesrapport", "adviesproject"}
ID_WOORDEN = {"briefadvies", "advies:", "advies", "adviesrapport", "adviesproject", "wetsadvies", "adviesvraag"}
NIET_ID_WOORDEN = {"samenvatting", "aanbiedingsbrief"}
NIET_HREF_ID_WOORDEN = {}

USER_AGENT = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) "
    "Gecko/20100101 Firefox/124.0 "
    "AdviescollegeScraper (+mailto:14605120@student.uva.nl; "
    "voor BSc-scriptie Informatiekunde UvA; "
    "doel: informatie inwinnen over verschillende adviescolleges)"
)

BASE_URL = (
    "https://www.gezondheidsraad.nl/documenten?"
    "filters%5B0%5D%5Bfield%5D=publication_date"
    "&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00"
    "&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom"
    "&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00"
    "&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo"
    "&filters%5B0%5D%5Btype%5D=all"
    "&filters%5B1%5D%5Bfield%5D=information_type"
    "&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies"
    "&filters%5B1%5D%5Btype%5D=all"
    "&filters%5B1%5D%5Bpersistent%5D=false"
)

env_path = r"C:\Users\31633\OneDrive\Bureaublad\OpenAI_API_Key.env"  
load_dotenv(env_path)
api_key = os.getenv("OPENAI_API_KEY")
print("Key geladen:", api_key is not None)
# Out:
# Key geladen: True

# %%
def beginSelenium():
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument(f"user-agent={USER_AGENT}")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )
    return driver

def aantalPaginas(driver):
    x = driver.find_element(
        By.CSS_SELECTOR,
        "#main-content > div.search-block > div.search-block__results > nav > ul > li:nth-child(7) > button > span.sr-only"
    )
    y = x.text.strip()
    pagina = re.sub(r"\D", "", y)
    return int(pagina)

driver = beginSelenium()
driver.get(BASE_URL)
time.sleep(2)

aantalPagina = aantalPaginas(driver)
print("Maximaal aantal pagina's om te controleren: " + str(aantalPagina))
print("-----------------------")

adviesURLS = []

for paginaNummer in range(1, aantalPagina + 1):
    if paginaNummer == 1:
        BASE_paginaURL = BASE_URL
    else:
        BASE_paginaURL = f"{BASE_URL}&current=n_{paginaNummer}_n"

    print("Pagina: " + str(paginaNummer))
    print(BASE_paginaURL)

    driver.get(BASE_paginaURL)
    time.sleep(2)

    li_items = driver.find_elements(
        By.CSS_SELECTOR,
        "ul.sui-results-container.links-list li.links-list__item"
    )
    count = 0
    for li in li_items:
        title_element = li.find_element(By.CSS_SELECTOR, "h3.link-plus__title")
        title_text = title_element.text.strip().lower()
        eerste_woord_titel = title_text.split()[0] if title_text else ""

        meta_spans = li.find_elements(
            By.CSS_SELECTOR,
            ".meta-data.link-plus__meta-data span"
        )

        meta_woorden = " ".join(
            span.text.strip().lower()
            for span in meta_spans
            if span.text.strip()
        )

        if meta_spans:
            doc_type = meta_spans[0].text.strip().lower()
        else:
            doc_type = ""

        alle_woorden = f"{title_text} {meta_woorden}".strip()

        # link + href
        a_tag = li.find_element(By.CSS_SELECTOR, "a.link-plus")
        href = a_tag.get_attribute("href")

        # eerste woord van de href
        href_delen = urlparse(href).path
        href_deel = href_delen.strip("/").split("/")[-1]
        eerste_woord = href_deel.split("-")[0].lower()

        # metadata check
        if (
            "advies" in doc_type
            and eerste_woord_titel not in NIET_ID_WOORDEN
            and eerste_woord not in NIET_HREF_ID_WOORDEN
            and "achtergronddocument" not in alle_woorden
            and "podcast" not in alle_woorden
        ):
            adviesURLS.append(href)
            count += 1
            continue

        # href check
        if eerste_woord in HREF_ID_WOORDEN:
            adviesURLS.append(href)
            count += 1
            continue

        # titel check
        if eerste_woord_titel in ID_WOORDEN:
            adviesURLS.append(href)
            count += 1
            continue
    time.sleep(5)
    print("aantal adviezen op de pagina: " + str(count))
    print("-------------------")

driver.quit()
# Out:
# Maximaal aantal pagina's om te controleren: 27
# -----------------------
# Pagina: 1
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false
# aantal adviezen op de pagina: 7
# -------------------
# Pagina: 2
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_2_n
# aantal adviezen op de pagina: 4
# -------------------
# Pagina: 3
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_3_n
# aantal adviezen op de pagina: 5
# -------------------
# Pagina: 4
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_4_n
# aantal adviezen op de pagina: 4
# -------------------
# Pagina: 5
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_5_n
# aantal adviezen op de pagina: 2
# -------------------
# Pagina: 6
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_6_n
# aantal adviezen op de pagina: 5
# -------------------
# Pagina: 7
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_7_n
# aantal adviezen op de pagina: 6
# -------------------
# Pagina: 8
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_8_n
# aantal adviezen op de pagina: 4
# -------------------
# Pagina: 9
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_9_n
# aantal adviezen op de pagina: 4
# -------------------
# Pagina: 10
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_10_n
# aantal adviezen op de pagina: 1
# -------------------
# Pagina: 11
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_11_n
# aantal adviezen op de pagina: 5
# -------------------
# Pagina: 12
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_12_n
# aantal adviezen op de pagina: 6
# -------------------
# Pagina: 13
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_13_n
# aantal adviezen op de pagina: 6
# -------------------
# Pagina: 14
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_14_n
# aantal adviezen op de pagina: 5
# -------------------
# Pagina: 15
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_15_n
# aantal adviezen op de pagina: 8
# -------------------
# Pagina: 16
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_16_n
# aantal adviezen op de pagina: 6
# -------------------
# Pagina: 17
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_17_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 18
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_18_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 19
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_19_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 20
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_20_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 21
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_21_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 22
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_22_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 23
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_23_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 24
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_24_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 25
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_25_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 26
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&filters%5B1%5D%5Bfield%5D=information_type&filters%5B1%5D%5Bvalues%5D%5B0%5D=Advies&filters%5B1%5D%5Btype%5D=all&filters%5B1%5D%5Bpersistent%5D=false&current=n_26_n
# aantal adviezen op de pagina: 10
# -------------------
# Pagina: 27
# https://www.gezondheidsraad.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all
# https://www.gezondheidsraad.nl/documenten/2020/02/18/emissies-van-ijzer--en-staalgieten
# https://www.gezondheidsraad.nl/documenten/2020/01/30/gezondheidsapps-en-wearables
# https://www.gezondheidsraad.nl/documenten/2020/01/27/wbo-reikwijdte-advies-hepatitisscreening
# https://www.gezondheidsraad.nl/documenten/2019/12/16/rol-diabetesverpleegkundige-bij-rijbewijsvernieuwing-voor-mensen-met-diabetes-mellitus
# https://www.gezondheidsraad.nl/documenten/2019/11/18/wbo-nipt-bij-meerlingzwangerschappen
# https://www.gezondheidsraad.nl/documenten/2019/11/06/loodinname-via-kraanwater
# https://www.gezondheidsraad.nl/documenten/2019/08/27/12-dichloorethaan
# https://www.gezondheidsraad.nl/documenten/2019/08/26/wbo-nipt-voor-zwangere-adolescenten-van-16-en-17-jaar
# https://www.gezondheidsraad.nl/documenten/2019/07/23/neonatale-screening-op-spinale-spieratrofie
# https://www.gezondheidsraad.nl/documenten/2019/07/17/de-regulering-van-cybriden-en-chimaeren
# https://www.gezondheidsraad.nl/documenten/2019/07/16/afkapwaarde-in-bevolkingsonderzoek-darmkanker
# https://www.gezondheidsraad.nl/documenten/2019/07/15/vaccinatie-tegen-gordelroos
# https://www.gezondheidsraad.nl/documenten/2019/07/10/gezondheidsrisicos-door-lage-concentraties-koolmonoxide
# https://www.gezondheidsraad.nl/documenten/2019/07/09/bevolkingsonderzoek-naar-aneurysma-van-de-abdominale-aorta-aaa
# https://www.gezondheidsraad.nl/documenten/2019/06/19/vaccinatie-tegen-hpv
# https://www.gezondheidsraad.nl/documenten/2019/05/21/goede-vertegenwoordiging
# https://www.gezondheidsraad.nl/documenten/2019/05/20/emissie-tijdens-kolenvergassing
# https://www.gezondheidsraad.nl/documenten/2019/05/15/herziening-eisen-rijgeschiktheid-bij-gebruik-geneesmiddelen
# https://www.gezondheidsraad.nl/documenten/2019/05/14/bewaartermijn-implantaatgegevens
# https://www.gezondheidsraad.nl/documenten/2019/04/04/veilige-zorg-goede-zorg
# https://www.gezondheidsraad.nl/documenten/2019/03/26/bisfenol-a
# https://www.gezondheidsraad.nl/documenten/2019/03/20/cadmium-en-anorganische-cadmium-verbindingen
# https://www.gezondheidsraad.nl/documenten/2019/03/13/dieselmotoremissie
# https://www.gezondheidsraad.nl/documenten/2019/02/18/plaatjesrijk-plasma
#
# Totaal aantal unieke adviezen-links: 188

# %%
res = []
for url in adviesURLS:
    client = OpenAI()

    prompt = f"""
    Lees dit document: {url}

    Vul de onderstaande JSON in volgens https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema:

    {{
        "dc_title": "",
        "foi_publishedDate": "",
        "dc_description": ""
    }}

    Regels:
    - Alleen écht gevonden info invullen.
    - Max 100 woorden in dc_description.
    - Ontbreekt iets? dan "" laten.
    - datum in jjjj-mm-dd
    - Output = alleen geldige JSON niks anders.
    """
    response = client.responses.create(
        model="gpt-5.1",
        input=prompt,
        tools=[{"type": "web_search"}],
        max_output_tokens=800,
    )
    
    json_str = response.output_text.strip()

    try:
        data = json.loads(json_str)
    except json.JSONDecodeError:
        print("Kon JSON niet parsen voor URL:", url)
        print("Ruwe output was:\n", json_str)
        continue

    data["dc_source"] = url
    data["dc_publisher"] = "oorg10218"
    data["dc_type"] = "2e"
        
    res.append(data)
    
    print(json.dumps(data, ensure_ascii=False, indent=2))
    
    time.sleep(12)

with open("GR_adviesScraper_data1.json", "w", encoding="utf-8") as f:
    json.dump(res, f, ensure_ascii=False, indent=2)
    
print("\nAlle JSON-data opgeslagen in GR_adviesScraper_data1.json")
# Out:
# {
#   "dc_title": "Advies Rijgeschiktheid na het doormaken van een psychose",
#   "foi_publishedDate": "2024-12-19",
#   "dc_description": "Adviesdocument van de Gezondheidsraad over rijgeschiktheid na het doormaken van een psychose.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/12/19/advies-rijgeschiktheid-na-het-doormaken-van-een-psychose",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Inzet van vernieuwde typen griepvaccins in het NPG",
#   "foi_publishedDate": "2024-12-17",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/12/17/advies-inzet-van-vernieuwde-typen-griepvaccins-in-het-npg",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Zicht op gehoorverlies bij kinderen en jongeren",
#   "foi_publishedDate": "2024-12-09",
#   "dc_description": "Adviesdocument van de Gezondheidsraad over zicht op gehoorverlies bij kinderen en jongeren. Het advies, oorspronkelijk gepubliceerd op 9 december 2024, is op 14 januari 2025 gecorrigeerd zonder inhoudelijke gevolgen voor de aanbevelingen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/12/09/advies-zicht-op-gehoorverlies-bij-kinderen-en-jongeren",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Aanpassing kwalificatie voedingsnorm voor selenium",
#   "foi_publishedDate": "2024-12-03",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/12/03/advies-aanpassing-kwalificatie-voedingsnorm-voor-selenium",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Voedingsnormen voor vitamines en mineralen voor lacterende vrouwen",
#   "foi_publishedDate": "2024-12-03",
#   "dc_description": "Adviesdocument van de Gezondheidsraad over voedingsnormen voor vitamines en mineralen voor vrouwen die borstvoeding geven, inclusief bijlagen met samenvatting, evaluatie en aanbiedingsbrief.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/12/03/advies-voedingsnormen-voor-vitamines-en-mineralen-voor-lacterende-vrouwen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Evaluatie Voedingsnormen voor vitamines en mineralen voor lacterende vrouwen",
#   "foi_publishedDate": "2024-12-03",
#   "dc_description": "Achtergronddocument bij het advies ‘Voedingsnormen voor vitamines en mineralen voor lacterende vrouwen’ van de Gezondheidsraad.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/12/03/evaluatie-voedingsnormen-voor-vitamines-en-mineralen-voor-lacterende-vrouwen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Vaccinatie van werknemers: kinkhoest",
#   "foi_publishedDate": "2024-09-30",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/09/30/advies-vaccinatie-werknemers-kinkhoest",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Respirabel kristallijn silica",
#   "foi_publishedDate": "2024-09-10",
#   "dc_description": "Advies van de Gezondheidsraad over respirabel kristallijn silica. De pagina bevat een Engelstalige download van het advies en bijlagen zoals een samenvatting, commentaar op het conceptadvies met reactie van de Gezondheidsraad, een aanbiedingsbrief en een persbericht, alle gedateerd 10-09-2024.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/09/10/advies-respirabel-kristallijn-silica",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Koolmonoxide; Gezondheidskundige advieswaarde voor beroepsmatige blootstelling",
#   "foi_publishedDate": "2024-09-03",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2024/09/03/advies-koolmonoxide",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Neonatale screening op OCTN2-deficiëntie",
#   "foi_publishedDate": "2024-07-01",
#   "dc_description": "Adviesdocument van de Gezondheidsraad

#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Rubberstof en rubberdamp",
#   "foi_publishedDate": "2023-07-03",
#   "dc_description": "Advies van de Gezondheidsraad over gezondheidsrisico’s van beroepsmatige blootstelling aan rubberstof en rubberdamp en de afleiding van gezondheidskundige advieswaarden of grenswaarden om werknemers beter te beschermen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/07/03/advies-rubberstof-en-rubberdamp",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Revaccinatie tegen COVID-19 met het HIPRA-vaccin",
#   "foi_publishedDate": "2023-06-29",
#   "dc_description": "Advies van de Subcommissie Vaccinaties COVID-19 van de Gezondheidsraad over de inzet van het door EMA goedgekeurde HIPRA-vaccin als revaccinatie voor personen vanaf 16 jaar die eerder een mRNA-vaccin van BioNTech/Pfizer of Moderna kregen, inclusief beoordeling van immuunrespons, (on)zekerheden over bescherming en bijwerkingen, en het advies het vaccin te reserveren voor mensen met een contra-indicatie of bezwaar tegen mRNA-vaccins.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/06/29/revaccinatie-tegen-covid-19-met-het-hipra-vaccin",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Structureel vaccinatieprogramma tegen COVID-19",
#   "foi_publishedDate": "2023-06-28",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/06/28/advies-structureel-vaccinatieprogramma-tegen-covid-19",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Vaccinatie van ouderen tegen pneumokokken (2023)",
#   "foi_publishedDate": "2023-06-20",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/06/20/advies-vaccinatie-van-ouderen-tegen-pneumokokken-2023",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Vaccinatie van kinderen tegen pneumokokken (2023)",
#   "foi_publishedDate": "2023-06-20",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/06/20/advies-vaccinatie-van-kinderen-tegen-pneumokokken-2023",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies WBO: Tomosynthese in het landelijk bevolkingsonderzoek borstkanker",
#   "foi_publishedDate": "2023-03-30",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/03/30/advies-wbo-tomosynthese-in-het-landelijk-bvo-borstkanker",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies BCG-vaccinatie en COVID-19; vervolgadvies",
#   "foi_publishedDate": "2023-03-29",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/03/29/advies-bcg-vaccinatie-en-covid-19-vervolgadvies",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Vaccinatie van werknemers: griep",
#   "foi_publishedDate": "2023-03-28",
#   "dc_description": "Adviesdocument van de Gezondheidsraad over vaccinatie van werknemers tegen griep, als onderdeel van de beroepsgebonden vaccinaties.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/03/28/advies-vaccinatie-van-werknemers-tegen-griep",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Trendanalyse biotechnologie 2023. Tijd voor een integrale visie.",
#   "foi_publishedDate": "2023-03-21",
#   "dc_description": "Advies van de Gezondheidsraad over de ontwikkelingen in de biotechnologie in 2023 en de noodzaak van een integrale visie van overheid en andere betrokken partijen op kansen, risico’s en ethische en maatschappelijke implicaties van biotechnologie in de gezondheidszorg en daarbuiten.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/03/21/trendanalyse-biotechnologie.-tijd-voor-een-integrale-visie",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Aanvaardbare bovengrenzen voor vitamines en mineralen",
#   "foi_publishedDate": "2023-03-07",
#   "dc_description": "Advies van de Gezondheidsraad over aanvaardbare bovengrenzen voor de inname van vitamines en mineralen, bedoeld als wetenschappelijk onderbouwde basis voor beleid en regelgeving rond voedingssupplementen en verrijkte voedingsmiddelen, ter bescherming van de volksgezondheid tegen mogelijke risico’s van te hoge innames.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023/03/07/advies-aanvaardbare-bovengrenzen-voor-vitamines-en-mineralen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies WBO: de niet-invasieve prenatale test (NIPT) als bevolkingsonderzoek",
#   "foi_publishedDate": "2023-02-20",
#   "dc_description": "Definitieve versie van het advies van de Gezondheidsraad over de niet-invasieve prenatale test (NIPT) als bevolkingsonderzoek, gepubliceerd onder de Wet op het bevolkingsonderzoek (WBO). Op 22 februari 2023 zijn twee kleine tekstuele wijzigingen doorgevoerd in het document.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2023
",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/11/08/advies-tin-en-geselecteerde-anorganische-tinverbindingen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Vaccinatie tegen meningokokken B: update",
#   "foi_publishedDate": "2022-10-12",
#   "dc_description": "Adviesdocument van de Gezondheidsraad over vaccinatie tegen meningokokken B. Het betreft een update van eerder advies, bedoeld als onafhankelijk wetenschappelijk advies voor regering en parlement over de inzet van meningokokken B-vaccinatie.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/10/12/advies-vaccinatie-tegen-meningokokken-b-update",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Vaccinatie tegen COVID-19 met het Novavax-vaccin bij adolescenten",
#   "foi_publishedDate": "2022-10-05",
#   "dc_description": "Het EMA heeft positief geoordeeld over gebruik van het Novavax-vaccin voor primaire COVID-19-vaccinatie bij 12- tot en met 17-jarigen. De Gezondheidsraad acht het aannemelijk dat het vaccin beschermt tegen ernstige COVID-19 door de omikronvariant en voldoende veilig is, maar wijst op beperkte gegevens bij jongeren en mogelijke zeldzame bijwerkingen. Daarom adviseert de raad het Novavax-vaccin alleen in te zetten voor basisvaccinatie van adolescenten die een bezwaar of contra-indicatie hebben voor een mRNA-vaccin.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/10/05/vaccinatie-tegen-covid-19-met-het-novavax-vaccin-bij-adolescenten",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Revaccinatie tegen COVID-19 met het Novavax-vaccin bij volwassenen",
#   "foi_publishedDate": "2022-10-05",
#   "dc_description": "Het EMA heeft positief geoordeeld over het gebruik van het COVID-19-vaccin van Novavax als herhaalprik voor volwassenen. De Gezondheidsraad adviseert het Novavax-vaccin niet als eerste keus voor revaccinatie vanwege onzekerheid over de bescherming tegen ernstige COVID-19 door de omikronvariant. De voorkeur gaat uit naar mRNA-vaccins, waarvan is aangetoond dat zij als herhaalprik bescherming tegen ernstige COVID-19 verhogen. Het Novavax-vaccin kan als alternatief worden gebruikt voor volwassenen met bezwaren tegen of contra-indicaties voor mRNA-vaccins.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/10/05/revaccinatie-tegen-covid-19-met-het-novavax-vaccin-bij-volwassenen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Afwegingskader testen van bloeddonaties",
#   "foi_publishedDate": "2022-09-15",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/09/15/advies-afwegingskader-testen-van-bloeddonaties",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Verduurzaming van hulpmiddelen in de zorg",
#   "foi_publishedDate": "2022-09-13",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/09/13/advies-verduurzaming-van-hulpmiddelen-in-de-zorg",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Evaluatie schema Rijksvaccinatieprogramma",
#   "foi_publishedDate": "2022-09-07",
#   "dc_description": "Advies van de Gezondheidsraad over het schema voor de evaluatie van het Rijksvaccinatieprogramma.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/09/07/advies-evaluatie-schema-rijksvaccinatieprogramma",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Aanpassing doses HPV-vaccinatie",
#   "foi_publishedDate": "2022-08-30",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/08/30/advies-aanpassing-doses-hpv-vaccinatie",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Voedingsnormen voor energie",
#   "foi_publishedDate": "2022-08-16",
#   "dc_description": "",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/08/16/advies-voedingsnormen-voor-energie",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "WBO: amendement bij proefbevolkingsonderzoek naar de invoering van de niet-invasieve prenatale test (NIPT)",
#   "foi_publishedDate": "2022-07-15",
#   "dc_description": "Het Amsterdam UMC heeft namens het NIPT Consortium een vergunning gevraagd voor het aanbieden van de niet-invasieve prenatale test (NIPT) aan zwangeren van 15 jaar en jonger. De Commissie Bevolkingsonderzoek van de Gezondheidsraad adviseert de minister van Volksgezondheid, Welzijn en Sport vergunning te verlenen, onder de voorwaarde dat de informatie aan de zwangere en haar (gezagdragende) ouder(s) of voogd(den) wordt aangepast.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022
covid-19",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Actualisatie advies vaccinatie van 5- tot en met 11-jarigen tegen COVID-19",
#   "foi_publishedDate": "2022-01-19",
#   "dc_description": "Begin december adviseerde de Gezondheidsraad om vaccinatie tegen COVID-19 beschikbaar te stellen aan (ouders van) kinderen van 5 tot en met 11 jaar die dit willen. Door de opkomst van de omikronvariant en een toename van het aantal kinderen dat COVID-19 heeft gehad, is het advies opnieuw beoordeeld. De raad concludeert dat het eerdere advies blijft gelden: vaccinatie moet beschikbaar zijn, mede vanwege het risico op MIS-C en de bescherming die vaccinatie daartegen waarschijnlijk biedt.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2022/01/19/actualisatie-advies-vaccinatie-van-5--tot-en-met-11-jarigen-tegen-covid-19",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Inzet vaccin van Janssen als booster",
#   "foi_publishedDate": "2021-12-24",
#   "dc_description": "Het Europees geneesmiddelenagentschap EMA heeft positief geoordeeld over het gebruik van het Janssen-vaccin als boosterprik. De Gezondheidsraad concludeert dat een booster met Janssen extra bescherming biedt en voldoende veilig is, maar dat er een risico bestaat op een zeldzame ernstige bijwerking (trombose met laag aantal bloedplaatjes), vooral bij jongere mensen. Antistoftoename is geringer dan bij mRNA-boosters en het langetermijneffect is onzeker. De raad adviseert daarom vooralsnog mRNA-vaccins als booster te verkiezen, tenzij andere overwegingen anders vragen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2021/12/24/inzet-vaccin-van-janssen-als-booster",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Vaccinatie tegen COVID-19 met het Novavax-vaccin bij volwassenen",
#   "foi_publishedDate": "2021-12-23",
#   "dc_description": "Advies van de Gezondheidsraad over de inzet van het Novavax-vaccin tegen COVID-19 bij volwassenen in Nederland, naar aanleiding van de positieve beoordeling door het EMA. Het advies vergelijkt werkzaamheid en veiligheid met mRNA-vaccins, bespreekt onzekerheden over bescherming tegen nieuwe varianten zoals omikron en adviseert primair gebruik van mRNA-vaccins. Novavax wordt genoemd als alternatief voor mensen met bezwaren tegen mRNA-vaccins. Het document beschrijft ook het schema van twee doses met minimaal drie weken interval.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2021/12/23/vaccinatie-tegen-covid-19-met-het-novavax-vaccin-bij-volwassenen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "WBO: onderzoek naar gepersonaliseerde darmkankerscreening",
#   "foi_publishedDate": "2021-12-20",
#   "dc_description": "Nederland kent sinds 2014 een bevolkingsonderzoek naar darmkanker waarbij mensen van 55 tot en met 75 jaar iedere twee jaar een uitnodiging krijgen. Erasmus MC wil onderzoeken of het rendement verbetert als het screeningsinterval wordt afgestemd op het individuele risico, met kortere intervallen voor hogere risico’s. De Commissie Bevolkingsonderzoek oordeelt dat het onderzoek wetenschappelijk deugdelijk is, geen grote risico’s voor deelnemers oplevert en voldoet aan de regels voor medisch handelen, en adviseert daarom om de gevraagde vergunning te verlenen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2021/12/20/wbo-onderzoek-naar-gepersonaliseerde-darmkankerscreening",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Evaluatie hielprikscreening: beoordelingskader en eerste inventarisatie",
#   "foi_publishedDate": "2021-12-14",
#   "dc_description": "In Nederland worden pasgeborenen via de hielprik gescreend op 25 ernstige, zeldzame aandoeningen. De Gezondheidsraad heeft, op verzoek van de staatssecretaris van VWS, criteria opgesteld voor de evaluatie van de hielprikscreening en een eerste evaluatie uitgevoerd van 11 aandoeningen. De raad concludeert dat screening voor de meeste van deze aandoeningen aanzienlijke gezondheidswinst oplevert die opweegt tegen nadelen zoals fout-positieve uitslagen. Voor de toekomst adviseert de raad periodieke evaluatie van alle aandoeningen, meer gegevensverzameling en meer onderzoek naar langetermijneffecten van screening.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2021/12

#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "COVID-19-vaccinatie van jonge kinderen met verhoogd medisch risico",
#   "foi_publishedDate": "2021-12-03",
#   "dc_description": "De Gezondheidsraad adviseert COVID-19-vaccinatie voor een deel van de 5-11 jarigen met verhoogd risico op een ernstig beloop van COVID-19, zoals kinderen met een chronische longaandoening, aangeboren hartafwijkingen of downsyndroom. Deze kinderen hebben meer kans op ziekenhuisopname en op een ernstige ontstekingsreactie (MIS-C). De raad adviseert kinderartsen deze kinderen te selecteren. Het EMA heeft het BioNTech/Pfizer-vaccin in aangepaste dosering voor 5-11 jaar goedgekeurd; dit werkt goed en is voldoende veilig. De beschikbare kinderdoses worden geadviseerd voor deze risicogroep.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2021/12/03/covid-19-vaccinatie-van-jonge-kinderen-met-verhoogd-medisch-risico",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Boostervaccinatie tegen COVID-19 bij personen van 18 tot 60 jaar",
#   "foi_publishedDate": "2021-11-25",
# ...
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "WBO: NIPT bij meerlingzwangerschappen",
#   "foi_publishedDate": "2019-11-18",
#   "dc_description": "Sinds enkele jaren is de niet-invasieve prenatale test (NIPT) beschikbaar voor zwangere vrouwen die prenatale screening willen op de syndromen van Down, Patau en Edwards (trisomie 21, 13 en 18). De Commissie Bevolkingsonderzoek van de Gezondheidsraad adviseert de staatssecretaris van VWS om een vergunning te verlenen zodat ook meerlingzwangerschappen in de lopende proefbevolkingsonderzoeken kunnen worden meegenomen, onder voorwaarde van goede monitoring en adequate informatievoorziening over voor- en nadelen en onzekerheden van de NIPT.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/11/18/wbo-nipt-bij-meerlingzwangerschappen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Loodinname via kraanwater",
#   "foi_publishedDate": "2019-11-06",
#   "dc_description": "Over het algemeen is drinkwater in Nederland van hoge kwaliteit en veilig om te drinken, maar een beperkt deel van de bevolking loopt gezondheidsrisico’s door hoge blootstelling aan lood via kraanwater, vooral bewoners van oude huizen met loden binnenleidingen. Zuigelingen met flesvoeding, jonge kinderen en zwangere vrouwen (inclusief het ongeboren kind) vormen risicogroepen. Bij kinderen kan hoge loodbelasting leiden tot een lager IQ. De Gezondheidsraad adviseert sanering van loden leidingen en tijdelijk flessenwater voor risicogroepen. In nieuwbouwhuizen kan tijdelijk een hoger loodgehalte voorkomen; daarom wordt doorspoelen aanbevolen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/11/06/loodinname-via-kraanwater",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Gezondheidskundige advieswaarde voor 1,2-Dichloorethaan",
#   "foi_publishedDate": "2019-08-27",
#   "dc_description": "De Gezondheidsraad beschrijft gezondheidskundige advieswaarden voor beroepsmatige blootstelling aan 1,2-dichloorethaan, een kankerverwekkende stof die genetische schade kan veroorzaken. De commissie GBBS schat luchtconcentraties die horen bij gestelde risiconiveaus (4 extra kankergevallen per 100.000 sterfgevallen en per 1.000) en adviseert rekening te houden met opname via de huid naast inhalatie.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/08/27/12-dichloorethaan",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "WBO: NIPT voor zwangere adolescenten van 16 en 17 jaar",
#   "foi_publishedDate": "2019-08-26",
#   "dc_description": "Sinds 2017 kunnen zwangere vrouwen die prenatale screening willen op de syndromen van Down, Patau en Edwards kiezen tussen de combinatietest of de niet-invasieve prenatale test (NIPT) als eerste test. Amsterdam UMC (locatie VUmc) heeft namens het NIPT-consortium een vergunning aangevraagd om ook zwangeren van 16 en 17 jaar op te nemen in deze proefbevolkingsonderzoeken. De Commissie Bevolkingsonderzoek van de Gezondheidsraad adviseert de staatssecretaris van VWS vergunning te verlenen en beveelt aan het toestemmingsregime van de Wet medisch-wetenschappelijk onderzoek met mensen toe te passen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019

#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Gezondheidsrisico’s door lage concentraties koolmonoxide",
#   "foi_publishedDate": "2019-07-10",
#   "dc_description": "Het inademen van koolmonoxide, bijvoorbeeld in een huis met een slecht functionerende cv-installatie, kan ook bij lage concentraties schadelijk zijn. De Wereldgezondheidsorganisatie adviseert langdurige blootstelling aan lage concentraties te vermijden. De Gezondheidsraad beveelt aan om koolmonoxidemelders af te stemmen op WHO-advieswaarden en in voorlichting meer aandacht te besteden aan de risico’s van langdurige blootstelling aan lage concentraties koolmonoxide.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/07/10/gezondheidsrisicos-door-lage-concentraties-koolmonoxide",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Bevolkingsonderzoek naar aneurysma van de abdominale aorta (AAA)",
#   "foi_publishedDate": "2019-07-09",
#   "dc_description": "Advies van de Gezondheidsraad over de vraag of in Nederland een systematisch bevolkingsonderzoek moet worden opgezet naar aneurysma van de abdominale aorta (AAA) bij mannen van 65 jaar. De raad concludeert dat de huidige opsporing via individuele patiëntenzorg effectief is en verwacht dat de meerwaarde van een bevolkingsonderzoek beperkt is en de nadelen, zoals extra operaties en risico op complicaties en sterfte, niet opwegen tegen de baten.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/07/09/bevolkingsonderzoek-naar-aneurysma-van-de-abdominale-aorta-aaa",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Vaccinatie tegen HPV",
#   "foi_publishedDate": "2019-06-19",
#   "dc_description": "Advies van de Gezondheidsraad om niet alleen meisjes maar ook jongens te vaccineren tegen HPV, omdat een HPV-infectie kan leiden tot verschillende vormen van kanker bij vrouwen en mannen. Vaccinatie werkt goed, is veilig, biedt groepsbescherming en is het meest effectief rond de leeftijd van 9 jaar. Extra gezondheidswinst is mogelijk als mensen tot en met 26 jaar die nog niet gevaccineerd zijn alsnog de gelegenheid krijgen zich te laten vaccineren.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/06/19/vaccinatie-tegen-hpv",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Goede vertegenwoordiging",
#   "foi_publishedDate": "2019-05-21",
#   "dc_description": "Het is van belang dat zorgverleners tijdig, bijvoorbeeld aan het begin van de behandelrelatie, bespreken wie de patiënt vertegenwoordigt als hij zelf geen beslissing kan nemen over zorg en behandeling. Dit kan een familielid zijn, iemand anders die de patiënt zelf heeft aangewezen of een mentor of curator. Knelpunten in de praktijk hebben vaak te maken met onduidelijkheid over de bevoegdheden van vertegenwoordigers en met gebrekkige communicatie. De Gezondheidsraad beveelt aan dat beroeps- en patiëntenverenigingen samen een handreiking opstellen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/05/21/goede-vertegenwoordiging",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Classificatievoorstel voor emissie tijdens kolenvergassing",
#   "foi_publishedDate": "2019-05-20",
#   "dc_description": "Kolenvergassing is een proces waarbij bruinkool of steenkool bij hoge temperaturen en druk wordt vergast. Bij incomplete kolenvergassing kunnen kankerverwekkende stoffen vrijkomen. De Subcommissie Classificatie carcinogene stoffen van de Gezondheidsraad adviseert de emissie tijdens kolenvergassing te classificeren als kankerverwekkend voor de mens (categorie 1A) en voor mutageniteit in categorie 2, wat wijst op mogelijke erfelijke mutaties in geslachtscellen.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/05/20/emissie-tijdens-kolenvergassing",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Herziening eisen rijgeschiktheid bij gebruik geneesmiddelen",
#   "foi_publishedDate": "2019-05-15",
#   "dc_description": "Sommige geneesmiddelen beïnvloeden de rijvaardigheid. De Commissie Rijgeschiktheid van de Gezondheidsraad beoordeelt welke aanpassingen nodig zijn in de regels voor rijgeschiktheid bij gebruik van categorie II- en III-geneesmiddelen. Het advies behelst uitzonderingen voor bepaalde antidepressiva in categorie III en strengere eisen, zoals een artsverklaring, voor beroepschauffeurs die categorie II-middelen gebruiken. Voor specifieke geneesmiddelen adviseert de commissie om voortaan te verwijzen naar de rijgeschiktheidsadviezen van de KNMP.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/05/15/herziening-eisen-rijgeschiktheid-bij-gebruik-geneesmiddelen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Bewaartermijn implantaatgegevens",
#   "foi_publishedDate": "2019-05-14",
#   "dc_description": "Gegevens over implantaten zouden 115 jaar bewaard moeten worden, gerekend vanaf de geboorte van de drager. Zo kunnen implantaten altijd worden opgespoord bij problemen, ook als ze al zijn verwijderd. De termijn geldt voor het Landelijk Implantaten Register en voor het deel van het medisch patiëntendossier dat het implantaat betreft; nu is de bewaartermijn voor medische dossiers minimaal vijftien jaar.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/05/14/bewaartermijn-implantaatgegevens",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Veilige zorg, goede zorg?",
#   "foi_publishedDate": "2019-04-04",
#   "dc_description": "De laatste decennia is veel geïnvesteerd in het veiliger maken van de zorg. Dit signalement onderzoekt hoe veiligheid in de zorg is geïmplementeerd en hoe de focus op risicobeheersing zich verhoudt tot de ontwikkeling en kwaliteit van zorg. Het CEG wil hiermee een bijdrage leveren aan de benodigde ethische reflectie op de vraag of veilige zorg hetzelfde is als goede zorg.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/04/04/veilige-zorg-goede-zorg",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Bisfenol A",
#   "foi_publishedDate": "2019-03-26",
#   "dc_description": "Bisfenol A (BPA) is een weekmaker die onder meer wordt gebruikt in plastic flessen. De stof is geclassificeerd als schadelijk voor de vruchtbaarheid (categorie 1B). Blootstelling kan leiden tot schade aan de ogen, allergische huidreacties en irritatie van de luchtwegen. Binnen de EU bestaan beperkingen voor het gebruik van bisfenol A. Voor beroepsmatige blootstelling geldt een grenswaarde van 2 mg/m3 lucht. De Commissie Gezondheid en beroepsmatige blootstelling aan stoffen (GBBS) adviseert een gezondheidskundige advieswaarde van 3,3 mg/m3 voor de inhaleerbare fractie.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/03/26/bisfenol-a",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Cadmium en anorganische cadmium verbindingen",
#   "foi_publishedDate": "2019-03-20",
#   "dc_description": "Mensen die op hun werk worden blootgesteld aan cadmium kunnen daar ziek van worden. Inademing kan leiden tot schade aan nieren en botten, tot longemfyseem en mogelijk tot longkanker. In 2010 stelde SCOEL een biologische limietwaarde en een gezondheidskundige advieswaarde voor. In 2017 volgde een nieuwe advieswaarde voor inhaleerbare cadmiumdeeltjes in lucht. De Commissie Gezondheid en beroepsmatige blootstelling aan stoffen vindt deze nieuwe waarde onvoldoende onderbouwd en adviseert om het eerdere advies aan te houden.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/03/20/cadmium-en-anorganische-cadmium-verbindingen",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Gezondheidskundige advieswaarde voor dieselmotoremissie",
#   "foi_publishedDate": "2019-03-13",
#   "dc_description": "Dieselmotoren worden gebruikt voor de aandrijving van voertuigen en generatoren. De roetdeeltjes in de uitlaatgassen van dieselmotoren kunnen onder meer longkanker veroorzaken. Er is geen veilig blootstellingsniveau aan te geven voor de blootstelling aan die roetdeeltjes. Het streven is om het aantal extra gevallen van kanker door beroepsmatige blootstelling te beperken tot 4 ten opzichte van het aantal gevallen van kanker per 100.000 sterfgevallen in de algemene bevolking.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/03/13/dieselmotoremissie",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Plaatjesrijk plasma",
#   "foi_publishedDate": "2019-02-18",
#   "dc_description": "Vooral in de cosmetische en sportgeneeskunde wordt plaatjesrijk plasma gebruikt, met veronderstelde gunstige effecten op wondgenezing en weefsel. Voor toepassingen zoals bij kaalheid, huidveroudering en in de geslachtsorganen is onduidelijk of er positieve effecten zijn. Er zijn aanwijzingen voor een positief effect bij tenniselleboog, chronische wonden en in de kaakchirurgie. Grote complicaties lijken niet op te treden, maar gedegen onderzoek ontbreekt. Voor verantwoorde toepassing zijn goed onderbouwde richtlijnen nodig over wat kwalitatief goede zorg is.",
#   "dc_source": "https://www.gezondheidsraad.nl/documenten/2019/02/18/plaatjesrijk-plasma",
#   "dc_publisher": "oorg10218",
#   "dc_type": "2e"
# }
#
# Alle JSON-data opgeslagen in GR_adviesScraper_data1.json

# %%
with open("GR_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 188

# %%
res2 = []

with open("GR_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

def retrieveLinksPagina2(driver, urltje):
    resje = {}
    driver.get(urltje)

    downloads = driver.find_elements(By.CSS_SELECTOR, "ul.download-list li.download-list__item")
    li_elements = driver.find_elements( By.CSS_SELECTOR, "#bijlagen ul.links-list li.links-list__item" )

    for download in downloads:
        title = download.find_element(By.CSS_SELECTOR, "span.title").text.strip()
        url = download.find_element(By.CSS_SELECTOR, "a.download-list__link").get_attribute("href")
        resje[title] = url

    for li in li_elements:
        title = li.find_element( By.CSS_SELECTOR, "span.link-plus__title" ).text.strip()
        url = li.find_element( By.CSS_SELECTOR, "a.link-plus" ).get_attribute("href")
        resje[title] = url

    try:
        knop = driver.find_element(By.CSS_SELECTOR, "a.button--cta")
        knoptitle = knop.text.strip()
        knopurl = knop.get_attribute("href")
        resje[knoptitle] = knopurl
    except NoSuchElementException:
        pass
    
    return resje    

driver = beginSelenium()

for item in data:
    dc_source2 = item.get("dc_source")

    urltjes = retrieveLinksPagina2(driver, dc_source2)

    foi_files = []
    for key, value in urltjes.items():
        if not value:
            continue
        foi_files.append({
            "foi_title": key,
            "foi_source": value,
        })

    res2.append({
        "dc_title": item.get("dc_title"),
        "foi_publishedDate": item.get("foi_publishedDate"),
        "dc_description": item.get("dc_description"),
        "dc_source": dc_source2,
        "dc_publisher": item.get("dc_publisher"),
        "dc_type": item.get("dc_type"),
        "foi_files": foi_files
    })

    time.sleep(5)

driver.quit()

with open("GR_adviesScraper_data2.json", "w", encoding="utf-8") as f:
    json.dump(res2, f, ensure_ascii=False, indent=2)

print("\nAlle JSON-data opgeslagen in ROB_adviesScraper_data2.json")
# Out:
# Alle JSON-data opgeslagen in ROB_adviesScraper_data2.json

# %%
with open("GR_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 188
