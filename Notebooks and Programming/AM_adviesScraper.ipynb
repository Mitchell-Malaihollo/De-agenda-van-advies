# %% [markdown]
# # AM_AdviesScraper
#
# Doel: AM adviezen uitgebracht vanaf 2019 tot en met 2024 verzamelen.
#
# Toepassing: Bachelor-scriptie Informatiekunde, Universiteit van Amsterdam
#
# Contact: mitchell.malaihollo@student.uva.nl
#
# Metadata Formatering volgens de [Woogle metadata specificatie](https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema)

# %%
import time
from urllib.parse import urljoin
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from openai import OpenAI
from dotenv import load_dotenv
import json
from selenium.common.exceptions import NoSuchElementException
from urllib.parse import urljoin, urlparse

# %%
# Aantal pagina's aanpassen

HREF_ID_WOORDEN = {"briefadvies", "wetsadvies", "advies", "adviesrapport", "adviesproject"}
ID_WOORDEN = {"briefadvies", "advies:", "advies", "adviesrapport", "adviesproject", "wetsadvies"}

USER_AGENT = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) "
    "Gecko/20100101 Firefox/124.0 "
    "AdviescollegeScraper (+mailto:14605120@student.uva.nl; "
    "voor BSc-scriptie Informatiekunde UvA; "
    "doel: informatie inwinnen over verschillende adviescolleges)"
)

BASE_URL = (
    "https://www.adviesraadmigratie.nl/documenten"
    "?filters%5B0%5D%5Bfield%5D=publication_date"
    "&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00"
    "&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom"
    "&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00"
    "&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo"
    "&filters%5B0%5D%5Btype%5D=all"
)

BASE = "https://www.adviesraadmigratie.nl"

env_path = r"C:\Users\31633\OneDrive\Bureaublad\OpenAI_API_Key.env"  
load_dotenv(env_path)
api_key = os.getenv("OPENAI_API_KEY")
print("Key geladen:", api_key is not None)
# Out:
# Key geladen: True

# %%
import re

def beginSelenium():
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument(f"user-agent={USER_AGENT}")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )
    return driver

def aantalPaginas():
    x = driver.find_element(
        By.CSS_SELECTOR,
        "#main-content > div.search-block > div.search-block__results > nav > ul > li:nth-child(7) > button > span.sr-only"
    )
    y = x.text.strip()
    pagina = re.sub(r"\D", "", y)
    return int(pagina)



driver = beginSelenium()
driver.get(BASE_URL)
time.sleep(2)
print("Maximaal aantal pagina's om te controleren: " + str(aantalPaginas()))
print("-----------------------")

adviesURLS = []
for paginaNummer in range(1, aantalPaginas() + 1):
    if paginaNummer == 1:
        BASE_paginaURL = BASE_URL
    else:
        BASE_paginaURL = f"{BASE_URL}&current=n_{paginaNummer}_n"

    print("Pagina: " + str(paginaNummer))
    print(BASE_paginaURL)

    driver.get(BASE_paginaURL)
    time.sleep(2)

    li_items = driver.find_elements(
        By.CSS_SELECTOR,
        "ul.sui-results-container.links-list li.links-list__item"
    )

    for li in li_items:
        meta_spans = li.find_elements(
            By.CSS_SELECTOR,
            ".meta-data.link-plus__meta-data span"
        )

        # metadata type
        doc_type = meta_spans[0].text.strip().lower()
        a_tag = li.find_element(By.CSS_SELECTOR, "a.link-plus")
        href = a_tag.get_attribute("href")
        if href.startswith("/"):
            href = BASE + href

        # eerste woord van de href
        href_delen = urlparse(href).path
        href_deel = href_delen.strip("/").split("/")[-1]
        eerste_woord = href_deel.split("-")[0]

        # eerste woord van de titel
        title_element = li.find_element(By.CSS_SELECTOR, "h3.link-plus__title")
        title_text = title_element.text.strip().lower()
        eerste_woord_titel = title_text.split()[0]
        
        # metadata check
        if "advies" in doc_type:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue

        # href eerste woord check
        if eerste_woord in HREF_ID_WOORDEN:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue

        # titel check dus Advies:
        if eerste_woord_titel in ID_WOORDEN:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue
    time.sleep(5)

    print("-------------------")
# Out:
# Maximaal aantal pagina's om te controleren: 13
# -----------------------
# Pagina: 1
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all
# https://www.adviesraadmigratie.nl/documenten/2024/09/10/adviesrapport-afgewogen-arbeidsmigratie
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2024/09/06/advies-wet-versterking-waarborgfunctie-awb
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2024/06/14/advies-over-wetsvoorstel-invoering-schorsende-werking-in-dublinzaken
# dit is een advies
# -
# -------------------
# Pagina: 2
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_2_n
# https://www.adviesraadmigratie.nl/documenten/2024/03/13/adviesrapport-geen-derderangsburgers.-de-risicos-voor-gedetacheerde-arbeidsmigranten-en-de-nederlandse-samenleving
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2023/09/27/advies-voor-de-nota-van-wijziging-bij-de-novelle-bij-het-wetsvoorstel-wet-terugkeer-en-vreemdelingenbewaring
# dit is een advies
# -
# -------------------
# Pagina: 3
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_3_n
# https://www.adviesraadmigratie.nl/documenten/2023/07/17/wetsadvies-besluit-en-regeling-ter-uitvoering-van-de-wet-gemeentelijke-taak-mogelijk-maken-asielopvangvoorzieningen
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2023/07/11/wetsadvies-wet-testen-bij-vertrek
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2023/05/24/wetsadvies-implementatie-herziene-europese-blauwe-kaart-richtlijn
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2023/05/22/advies-wijziging-rijkswet-op-het-nederlanderschap-tot-herziening-van-verlies-van-rechtswege-wegens-langdurig-verblijf-buiten-het-koninkrijk-en-de-eu
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2023/03/10/adviesrapport-de-onvolledige-implementatie-van-europese-richtlijnen
# dit is een advies
# -
# -------------------
# Pagina: 4
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_4_n
# https://www.adviesraadmigratie.nl/documenten/2022/12/21/adviesrapport-realisme-rond-richtgetallen-kansen-en-risicos-van-streefcijfers-en-quota-in-het-migratiebeleid
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2022/11/23/wetsadvies-gemeentelijke-taak-asielopvangvoorzieningen
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2022/10/18/adviesrapport-een-huis-voor-statushouder
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2022/09/27/adviesrapport-zorgvuldig-arbeidsmigratiebeleid
# dit is een advies
# -
# -------------------
# Pagina: 5
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_5_n
# https://www.adviesraadmigratie.nl/documenten/2022/05/13/wetsadvies-besluit-evidente-staatloosheid
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2022/03/17/input-adviesraad-migratie-t.b.v.-vkc-22-3-22-wijzigingen-vw2000
# dit is een advies
# -
# -------------------
# Pagina: 6
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_6_n
# https://www.adviesraadmigratie.nl/documenten/2021/12/17/wetsadvies-over-wijziging-van-de-vreemdelingenwet-2000-voor-het-gebruik-van-biometrie-bij-automatische-grenscontrole
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2021/11/05/advies-over-wijziging-van-de-wet-inburgering-2021-opnemen-van-een-hardheidsclausule-en-aanpassing-van-het-overgangsrecht
# dit is een advies
# -
# -------------------
# Pagina: 7
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_7_n
# https://www.adviesraadmigratie.nl/documenten/2021/07/08/grip-houden-op-publieke-belangen-onderzoek-naar-privatisering-in-het-migratiebeleid
# dit is een advies
# -
# -------------------
# Pagina: 8
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_8_n
# https://www.adviesraadmigratie.nl/documenten/2021/04/22/advies-samen-werken-aan-terugkeer
# dit is een advies
# -
# -------------------
# Pagina: 9
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_9_n
# https://www.adviesraadmigratie.nl/documenten/2021/03/23/inburgering-is-geen-bijzaak
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2021/02/04/wetsadvies-voorstel-wijziging-rijkswet-nederlanderschap
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2021/01/14/wetsadvies-over-ontwerpbesluit-naturalisatietoets-2021
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2021/01/07/advies-wijziging-vb-regelen-aanmeldfase-en-vervallen-eerste-gehoor
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/12/23/advies-startupregeling
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/12/11/wetsadvies-wetsvoorstel-aanscherping-openbare-orde
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/12/11/wetsadvies-afschaffing-dwangsommen
# dit is een advies
# -
# -------------------
# Pagina: 10
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_10_n
# https://www.adviesraadmigratie.nl/documenten/2020/11/9/voorstel-van-wet-tot-wijziging-van-boek-10-van-het-burgerlijkwetboek-in-verband-met-de-uitsluiting-van-de-erkenning-van-kindhuwelijken
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/10/21/wetsadvies-besluit-en-regeling-inburgering
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/10/13/advies-wijziging-wet-terugkeer-en-vreemdelingenbewaring
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/10/09/wijziging-rijkswet-op-het-nederlanderschap-in-verband-met-het-arrest-tjebbes
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/10/02/wetsadvies-initiatiefvoorstel-van-wet-wijziging-vreemdelingenwet-in-verband-met-verankeren-van-het-belang-van-het-kind
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/09/24/wetsadvies-besluit-uitvoering-wav
# dit is een advies
# -
# -------------------
# Pagina: 11
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_11_n
# https://www.adviesraadmigratie.nl/documenten/2020/06/16/wetsadvies-over-tijdelijke-wet-opschorting-dwangsommen-ind
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/05/25/weten-en-wegen
# dit is een advies
# -
# -------------------
# Pagina: 12
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_12_n
# https://www.adviesraadmigratie.nl/documenten/2020/03/03/advies-voorstel-wet-tot-wijziging-van-wet-arbeid-vreemdelingen
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/03/09/advies-wetsvoorstel-tot-verlenging-wet-biometrie-vreemdelingenketen
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/02/10/wetsvoorstel-tot-wijziging-participatiewet
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2020/01/31/vervoerdersverplichtingen
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2019/11/05/secundaire-migratie
# dit is een advies
# -
# -------------------
# Pagina: 13
# https://www.adviesraadmigratie.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_13_n
# https://www.adviesraadmigratie.nl/documenten/2019/09/11/wet-inburgering
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2019/06/26/afschaffing-discretionaire-bevoegdheid
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2019/03/13/marktwerking-inburgeringsonderwijs
# dit is een advies
# -
# https://www.adviesraadmigratie.nl/documenten/2019/02/18/veranderend-ouderschap-en-migratie
# dit is een advies
# -
# -------------------

# %%
print("\nAlle unieke adviezen links:")
for link in adviesURLS:
    print(link)

print(f"\nTotaal aantal unieke adviezen-links: {len(adviesURLS)}")
# Out:
# Alle unieke adviezen links:
# https://www.adviesraadmigratie.nl/documenten/2024/09/10/adviesrapport-afgewogen-arbeidsmigratie
# https://www.adviesraadmigratie.nl/documenten/2024/09/06/advies-wet-versterking-waarborgfunctie-awb
# https://www.adviesraadmigratie.nl/documenten/2020/12/11/wetsadvies-wetsvoorstel-aanscherping-openbare-orde
# https://www.adviesraadmigratie.nl/documenten/2020/12/11/wetsadvies-afschaffing-dwangsommen
# https://www.adviesraadmigratie.nl/documenten/2020/11/9/voorstel-van-wet-tot-wijziging-van-boek-10-van-het-burgerlijkwetboek-in-verband-met-de-uitsluiting-van-de-erkenning-van-kindhuwelijken
# https://www.adviesraadmigratie.nl/documenten/2020/10/21/wetsadvies-besluit-en-regeling-inburgering
# https://www.adviesraadmigratie.nl/documenten/2020/10/13/advies-wijziging-wet-terugkeer-en-vreemdelingenbewaring
# https://www.adviesraadmigratie.nl/documenten/2020/10/09/wijziging-rijkswet-op-het-nederlanderschap-in-verband-met-het-arrest-tjebbes
# https://www.adviesraadmigratie.nl/documenten/2020/10/02/wetsadvies-initiatiefvoorstel-van-wet-wijziging-vreemdelingenwet-in-verband-met-verankeren-van-het-belang-van-het-kind
# https://www.adviesraadmigratie.nl/documenten/2020/09/24/wetsadvies-besluit-uitvoering-wav
# https://www.adviesraadmigratie.nl/documenten/2020/06/16/wetsadvies-over-tijdelijke-wet-opschorting-dwangsommen-ind
# https://www.adviesraadmigratie.nl/documenten/2020/05/25/weten-en-wegen
# https://www.adviesraadmigratie.nl/documenten/2020/03/03/advies-voorstel-wet-tot-wijziging-van-wet-arbeid-vreemdelingen
# https://www.adviesraadmigratie.nl/documenten/2020/03/09/advies-wetsvoorstel-tot-verlenging-wet-biometrie-vreemdelingenketen
# https://www.adviesraadmigratie.nl/documenten/2020/02/10/wetsvoorstel-tot-wijziging-participatiewet
# https://www.adviesraadmigratie.nl/documenten/2020/01/31/vervoerdersverplichtingen
# https://www.adviesraadmigratie.nl/documenten/2019/11/05/secundaire-migratie
# https://www.adviesraadmigratie.nl/documenten/2019/09/11/wet-inburgering
# https://www.adviesraadmigratie.nl/documenten/2019/06/26/afschaffing-discretionaire-bevoegdheid
# https://www.adviesraadmigratie.nl/documenten/2019/03/13/marktwerking-inburgeringsonderwijs
# https://www.adviesraadmigratie.nl/documenten/2019/02/18/veranderend-ouderschap-en-migratie
#
# Totaal aantal unieke adviezen-links: 44

# %%
res = []
for url in adviesURLS:
    client = OpenAI()

    prompt = f"""
    Lees dit document: {url}

    Vul de onderstaande JSON in volgens https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema:

    {{
        "dc_title": "",
        "foi_publishedDate": "",
        "dc_description": ""
    }}

    Regels:
    - Alleen écht gevonden info invullen.
    - Max 100 woorden in dc_description.
    - Ontbreekt iets? dan dat veld "" laten.
    - datum in jjjj-mm-dd van het daadwerkelijke gepubliceerde advies.
    - Output = alleen geldige JSON niks anders.
    """
    response = client.responses.create(
        model="gpt-5.1",
        input=prompt,
        tools=[{"type": "web_search"}],
        max_output_tokens=800,
    )
    
    json_str = response.output_text.strip()

    try:
        data = json.loads(json_str)
    except json.JSONDecodeError:
        print("Kon JSON niet parsen voor URL:", url)
        print("Ruwe output was:\n", json_str)
        continue

    data["dc_source"] = url
    data["dc_publisher"] = "oorg10252"
    data["dc_type"] = "2e"
        
    res.append(data)
    
    print(json.dumps(data, ensure_ascii=False, indent=2))
    
    time.sleep(12)

with open("AM_adviesScraper_data1.json", "w", encoding="utf-8") as f:
    json.dump(res, f, ensure_ascii=False, indent=2)
    
print("\nAlle JSON-data opgeslagen in AM_adviesScraper_data1.json")
# Out:
# {
#   "dc_title": "Advies ‘Afgewogen arbeidsmigratie. Gericht arbeidsmigratiebeleid voor brede welvaart'",
#   "foi_publishedDate": "2024-09-10",
#   "dc_description": "De Adviesraad Migratie pleit in dit adviesrapport voor een arbeidsmigratiebeleid dat niet alleen uitgaat van economische groei, maar ook van maatschappelijke en ecologische effecten, in lijn met het concept brede welvaart. Het rapport schetst hoe een brede‑welvaartsbenadering van arbeidsmigratie kan worden uitgewerkt, met onder meer bandbreedtes voor het aantal arbeidsmigranten en een brede welvaartstoets voor toelating van arbeidsmigranten van buiten de EU.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2024/09/10/adviesrapport-afgewogen-arbeidsmigratie",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Wet versterking waarborgfunctie Awb",
#   "foi_publishedDate": "2024-07-31",
#   "dc_description": "Advies van de Adviesraad Migratie over de voorgestelde aanpassingen voor de Wet versterking waarborgfunctie Algemene wet bestuursrecht (Awb), toegespitst op het migratiedomein. De raad adviseert onder meer om het dienstbaarheidsbeginsel en passend contact met de overheid ook op asielzaken toe te passen, de financiële paragraaf en uitvoeringstoetsen te betrekken bij de beoordeling van de uitvoerbaarheid voor de IND, en bijzondere bepalingen in de Vw2000 in het kader van het wetsvoorstel te beoordelen en zo nodig te wijzigen.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2024/09/06/advies-wet-versterking-waarborgfunctie-awb",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over wetsvoorstel invoering schorsende werking in Dublinzaken",
#   "foi_publishedDate": "2024-04-22",
#   "dc_description": "Adviesraad Migratie brengt advies uit over een voorstel tot wijziging van de Vreemdelingenwet 2000 om schorsende werking in te voeren bij beroep tegen besluiten waarbij asielaanvragen op grond van artikel 30 Vw2000 niet in behandeling zijn genomen. De raad heeft geen juridische bezwaren, maar beveelt aan de motivering van het wetsvoorstel te heroverwegen, omdat onvoldoende is gemotiveerd of via rechtspraak al naar oplossingen is gezocht en of wetgeving noodzakelijk is om het gewenste effect in Dublinzaken te bereiken.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2024/06/14/advies-over-wetsvoorstel-invoering-schorsende-werking-in-dublinzaken",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport: 'Geen derderangsburgers. De risico’s voor gedetacheerde arbeidsmigranten en de Nederlandse samenleving'",
#   "foi_publishedDate": "2024-03-13",
#   "dc_description": "De Adviesraad Migratie onderzoekt de risico’s voor gedetacheerde arbeidsmigranten, van wie een groeiend aantal via bedrijven in andere EU-lidstaten in Nederland werkt. Door verschillen in regelgeving en ondoorzichtige constructies lopen zij risico op onderbetaling, slechte arbeidsvoorwaarden en beperkte sociale zekerheid. Het rapport signaleert dat deze ‘concurrentiedetachering’ niet alleen schadelijk is voor arbeidsmigranten zelf, maar ook voor de Nederlandse arbeidsmarkt en samenleving, en bevat aanbevelingen om misbruik tegen te gaan en de rechtspositie van deze werknemers te versterken.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2024/03/13/adviesrapport-geen-derderangsburgers.-de-risicos-voor-gedetacheerde-arbeidsmigranten-en-de-nederlandse-samenleving",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adv

#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over wijziging van de Rijkswet op het Nederlanderschap tot herziening van verlies van rechtswege wegens langdurig verblijf buiten het koninkrijk en de EU",
#   "foi_publishedDate": "2023-05-22",
#   "dc_description": "Op 22 mei 2023 bracht de Adviesraad Migratie advies uit over een voorstel tot wijziging van de Rijkswet op het Nederlanderschap. Het gaat om de herziening van de regeling van verlies van rechtswege van het Nederlanderschap bij langdurig verblijf buiten het Koninkrijk en de EU, en een tijdelijke mogelijkheid tot herkrijging. De adviesraad beveelt aan om het automatische verlies van de Nederlandse nationaliteit na langdurig verblijf buiten het Koninkrijk en de EU te schrappen, omdat dit op gespannen voet staat met het rechtszekerheidsbeginsel.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2023/05/22/advies-wijziging-rijkswet-op-het-nederlanderschap-tot-herziening-van-verlies-van-rechtswege-wegens-langdurig-verblijf-buiten-het-koninkrijk-en-de-eu",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "De (onvolledige) implementatie van Europese richtlijnen. Advies over ontwerpbesluit tot wijziging van het Vreemdelingenbesluit 2000",
#   "foi_publishedDate": "2023-03-10",
#   "dc_description": "Advies van de Adviesraad Migratie over het ontwerpbesluit tot wijziging van het Vreemdelingenbesluit 2000 (en enkele andere besluiten). De raad signaleert dat de Nederlandse wetgever EU-richtlijnen vaak minimaal en onvolledig implementeert door deze in te passen in bestaande regelgeving en praktijk. Dit kan ertoe leiden dat de rechtspraktijk jarenlang niet in overeenstemming is met fundamentele waarborgen uit EU-richtlijnen. De raad beveelt aan de implementatiewerkwijze te evalueren en hem structureel te consulteren bij de implementatie van richtlijnen.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2023/03/10/adviesrapport-de-onvolledige-implementatie-van-europese-richtlijnen",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Realisme rond richtgetallen - Kansen en risico’s van streefcijfers en quota in het migratiebeleid",
#   "foi_publishedDate": "2022-12-21",
#   "dc_description": "Adviesrapport van de Adviesraad Migratie over het gebruik van beleidsmatige richtgetallen in het migratiedomein. Het rapport analyseert kansen en risico’s van zachte streefcijfers en harde quota, benadrukt verschillen tussen asiel- en arbeidsmigratie en bespreekt voorwaarden voor realistisch gebruik van richtgetallen, zoals beleidsruimte en betrokkenheid van burgers en uitvoeringsorganisaties. Het Canadese model dient als inspiratiebron.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2022/12/21/adviesrapport-realisme-rond-richtgetallen-kansen-en-risicos-van-streefcijfers-en-quota-in-het-migratiebeleid",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Wetsadvies over Wet gemeentelijke taak mogelijk maken asielopvangvoorzieningen",
#   "foi_publishedDate": "2022-11-23",
#   "dc_description": "Met dit wetsvoorstel krijgen gemeenten een expliciete wettelijke taak om opvang van asielzoekers door het COA mogelijk te maken en opvangvoorzieningen evenwichtiger over gemeenten te verdelen. De wet, als spoedwetgeving, regelt hoofdlijnen die later in lagere regelgeving worden uitgewerkt. De Adviesraad Migratie is positief over de wettelijke verplichting voor gemeenten, keuzevrijheid in de manier van realiseren, flexibele opvangvoorzieningen voor asielzoekers en andere aandachtsgroepen en de mogelijkheid dat gemeenten zelf opvangvoorzieningen exploiteren. Daarnaast doet de raad voorstellen om ramings- en verdeelcycli, financiering en taakverdeling te verbeteren.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2022/11/23/wetsadvies-gemeentelijke-taak-asielopvangvoorzieningen",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Een huis voor statushouders",
#   "foi_publishedDate": "2022-10-18",
#   "dc_description": "Adviesraad Migratie beschrijft hoe langdurig verblijf van statushouders in COA-opvang hun integratie belemmert en opvangplekken bezet houdt. Door wooncrisis, een noodsituatie in het asielstelsel en knelpunten bij lokale uitvoering komen statushouders moeilijk aan passende huisvesting. De raad adviseert maatregelen op het gebied van wonen, een robuust asielstelsel en verbetering van de koppeling van statushouders aan gemeenten, waaronder meer investeren in flexwoningen, wettelijke verplichtingen voor gemeenten rond urgentie en opvang, en betere informatievoorziening door het COA aan gemeenten.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2022/10/18/adviesrapport-een-huis-voor-statushouder",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport ‘Zorgvuldig arbeidsmigratiebeleid. Hoe de langdurige zorg profijt kan hebben van vakmigranten’",
#   "foi_publishedDate": "2022-09-28",
#   "dc_description": "De Adviesraad Migratie adviseert om met zendende landen partnerschappen te ontwikkelen voor ‘vakmigranten’ in verplegende en verzorgende beroepen (vanaf mbo niveau-3) om huidige en toekomstige personeelstekorten in de langdurige zorg tegen te gaan. Specifieke en gerichte arbeidsmigratie moet onderdeel zijn van een breder pakket aan arbeidsmarktmaatregelen. Beleidscondities moeten waarborgen dat arbeidsmigrantenrechten, inbedding in de samenleving en brede welvaart centraal staan, met wederzijds voordeel voor zendende en ontvangende landen.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2022/09/27/adviesrapport-zorgvuldig-arbeidsmigratiebeleid",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over het ontwerpbesluit evidente staatloosheid",
#   "foi_publishedDate": "2022-05-13",
#   "dc_description": "Advies van de Adviesraad Migratie over het ontwerpbesluit evidente staatloosheid. De raad constateert dat de vier in het besluit opgenomen situaties waarin evidente staatloosheid wordt aangenomen in logisch verband staan met de in de toelichting geformuleerde uitgangspunten. Het besluit beoogt te voorkomen dat in gevallen waarin staatloosheid eenvoudig kan worden vastgesteld onnodig een juridische procedure moet worden doorlopen, wat tijd en middelen bespaart voor zowel de staatloze als de overheid.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2022/05/13/wetsadvies-besluit-evidente-staatloosheid",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Input adviesraad migratie t.b.v. VKC 22-3-22 (wijzigingen Vw2000)",
#   "foi_publishedDate": "2022-03-17",
#   "dc_description": "Op 22 maart 2022 spreekt de Tweede Kamer in een technische briefing over twee wetsvoorstellen: aanpassing van de geldigheidsduur van de verblijfsvergunning asiel voor bepaalde tijd van vijf naar drie jaar, en herziening van de regels voor niet tijdig beslissen op aanvragen (afschaffing dwangsommen). De Adviesraad Migratie brengt in dit document eerdere, kritische advisering over beide wetsvoorstellen opnieuw onder de aandacht.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2022/03/17/input-adviesraad-migratie-t.b.v.-vkc-22-3-22-wijzigingen-vw2000",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Wetsadvies over wijziging van de Vreemdelingenwet 2000 voor het gebruik van biometrie bij automatische grenscontrole",
#   "foi_publishedDate": "2021-12-17",
#   "dc_description": "Wetsadvies aan het kabinet over een voorstel tot wijziging van de Vreemdelingenwet 2000 voor het gebruik van biometrische gegevens bij automatische grenscontroles (e-gates). De adviesraad acht het niet aannemelijk dat een zwaarwegend belang het verwerken en opslaan van biometrische gegevens in e-gates noodzakelijk maakt en adviseert in deze vorm af te zien van het wetsvoorstel, mede vanwege de grote inbreuk op de privacy van reizigers en het ontbreken van proportionaliteit.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2021/12/17/wetsadvies-over-wijziging-van-de-vreemdelingenwet-2000-voor-het-gebruik-van-biometrie-bij-automatische-grenscontrole",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies
",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2021/02/04/wetsadvies-voorstel-wijziging-rijkswet-nederlanderschap",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over ontwerpbesluit Naturalisatietoets 2021",
#   "foi_publishedDate": "2021-01-14",
#   "dc_description": "De Adviesraad Migratie (voorheen ACVZ) uit zorgen over de consequenties van het ontwerpbesluit voor de naturalisatie tot Nederlander, in het bijzonder de verhoging van het vereiste taalniveau van A2 naar B1. Dit kan ertoe leiden dat migranten langdurig in Nederland verblijven zonder de Nederlandse nationaliteit te kunnen verkrijgen. De raad adviseert onder meer een overgangstermijn van drie jaar en tijdige, gerichte informatievoorziening aan (potentieel) inburgeringsplichtige migranten over de strengere naturalisatie-eisen.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2021/01/14/wetsadvies-over-ontwerpbesluit-naturalisatietoets-2021",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over het regelen van de aanmeldfase en het vervallen van het eerste gehoor in de algemene asielprocedure",
#   "foi_publishedDate": "2021-01-07",
#   "dc_description": "De Adviesraad Migratie (voorheen ACVZ) beoordeelt het voorstel tot wijziging van het Vreemdelingenbesluit 2000 dat de aanmeldfase regelt, het eerste gehoor in de algemene asielprocedure laat vervallen en enkele technische aanpassingen doorvoert. De raad ziet het formaliseren van het aanmeldgehoor als positieve aanvulling, maar plaatst kritische kanttekeningen bij het vragen naar asielmotieven in de aanmeldfase, onder meer vanwege waarborgen voor minderjarige en kwetsbare asielzoekers en de gevolgen voor de beoordeling van de geloofwaardigheid.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2021/01/07/advies-wijziging-vb-regelen-aanmeldfase-en-vervallen-eerste-gehoor",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies: Voorbij de opstartfase",
#   "foi_publishedDate": "2020-12-23",
#   "dc_description": "In dit advies binnen de reeks ‘De rol van private actoren in het migratiebeleid’ bespreekt de ACVZ de begeleiding van buitenlandse startup-ondernemers in Nederland. De raad benadrukt hun positieve bijdrage aan het Nederlandse startup-ecosysteem, maar vraagt aandacht voor de legitimiteit van de startup-regeling en de rechtsbescherming van deskundige begeleiders en startup-ondernemers.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2020/12/23/advies-startupregeling",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Wetsadvies over voorstel aanscherping openbare-ordebeleid",
#   "foi_publishedDate": "2020-12-11",
#   "dc_description": "De Adviesraad Migratie (voorheen ACVZ) beoordeelt het conceptwetsvoorstel tot wijziging van de Vreemdelingenwet inzake aanscherping van het openbare-ordebeleid voor vreemdelingen met criminele antecedenten. De raad concludeert dat de noodzaak van de wetswijziging onvoldoende is onderbouwd, dat het voorstel disproportioneel is en dat verschillen worden vergroot tussen Nederlandse burgers en vreemdelingen die al lang in Nederland wonen. Het advies bevat diverse aanbevelingen om de noodzaak, proportionaliteit en motivering van de voorgestelde maatregel beter te onderbouwen.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2020/12/11/wetsadvies-wetsvoorstel-aanscherping-openbare-orde",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over herziening van de regels voor niet tijdig beslissen op aanvragen op grond van de Vreemdelingenwet 2000",
#   "foi_publishedDate": "2020-12-11",
#   "dc_description": "Wetsadvies van de Adviesraad Migratie (voorheen ACVZ) over het wetsvoorstel tot herziening van de regels voor niet tijdig beslissen op aanvragen op grond van de Vreemdelingenwet 2000, inclusief de voorgestelde afschaffing van dwangsommen. De raad adviseert onder meer de maximale beslistermijn voor asielaanvragen in de wet op te nemen, de afschaffing van dwangsommen te heroverwegen en te motiveren waarom de afschaffing ook voor reguliere verblijfsaanvragen zou moeten gelden.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2020

#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies: Marktwerking inburgeringsonderwijs",
#   "foi_publishedDate": "2019-03-13",
#   "dc_description": "De Adviescommissie voor Vreemdelingenzaken (ACVZ) onderzocht hoe de markt voor inburgeringsonderwijs de afgelopen jaren was ingericht en functioneerde. De commissie concludeert dat het stelsel gebrekkig was, waardoor inburgeringsplichtigen hun rol als consument vaak niet goed konden vervullen. Het advies is onderdeel van breder onderzoek naar de rol van private actoren in het migratiedomein en beoogt bij te dragen aan een evenwichtiger stelsel met kwalitatief goed inburgeringsonderwijs.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2019/03/13/marktwerking-inburgeringsonderwijs",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies: Veranderend ouderschap en migratie",
#   "foi_publishedDate": "2019-02-18",
#   "dc_description": "De Adviescommissie voor Vreemdelingenzaken (ACVZ) adviseert over de vreemdelingenrechtelijke gevolgen van voorstellen voor meerouderschap, meerpersoonsgezag en een draagmoederschapsregeling uit het rapport ‘Kind en ouders in de 21ste eeuw’ van de Staatscommissie Herijking ouderschap. De ACVZ acht het gewenst dat de gewijzigde gezinsdefinitie in het afstammingsrecht ook in het vreemdelingenrecht wordt doorgevoerd en doet aanbevelingen om oneigenlijk gebruik van regelingen te voorkomen, onder meer via waarborgen in de wet en beperking van toegang tot de draagmoederschapsregeling tot Unieburgers en vreemdelingen met een permanent verblijfsrecht.",
#   "dc_source": "https://www.adviesraadmigratie.nl/documenten/2019/02/18/veranderend-ouderschap-en-migratie",
#   "dc_publisher": "oorg10252",
#   "dc_type": "2e"
# }
#
# Alle JSON-data opgeslagen in AM_adviesScraper_data1.json

# %%
with open("AM_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 44

# %%
res2 = []

with open("AM_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

def retrieveLinksPagina2(driver, urltje):
    resje = {}
    driver.get(urltje)

    # Alle <li> elementen ophalen
    li_elements = driver.find_elements(By.CSS_SELECTOR, "ul.download-list li.download-list__item")
    
    for li in li_elements:
        # Titel ophalen
        title = li.find_element(By.CSS_SELECTOR, "span.title").text.strip()
        
        # Download link ophalen
        url = li.find_element(By.CSS_SELECTOR, "a.download-list__link").get_attribute("href")
    
        # In dictionary zetten
        resje[title] = url
        
    return resje    

driver = beginSelenium()

for item in data:
    dc_source2 = item.get("dc_source")

    urltjes = retrieveLinksPagina2(driver, dc_source2)

    foi_files = []
    for key, value in urltjes.items():
        if not value:
            continue
        foi_files.append({
            "foi_title": key,
            "foi_source": value,
        })

    res2.append({
        "dc_title": item.get("dc_title"),
        "foi_publishedDate": item.get("foi_publishedDate"),
        "dc_description": item.get("dc_description"),
        "dc_source": dc_source2,
        "dc_publisher": item.get("dc_publisher"),
        "dc_type": item.get("dc_type"),
        "foi_files": foi_files
    })

    time.sleep(5)

driver.quit()

with open("AM_adviesScraper_data2.json", "w", encoding="utf-8") as f:
    json.dump(res2, f, ensure_ascii=False, indent=2)

print("\nAlle JSON-data opgeslagen in AM_adviesScraper_data2.json")
# Out:
# Alle JSON-data opgeslagen in AM_adviesScraper_data2.json

# %%
with open("AM_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 44
