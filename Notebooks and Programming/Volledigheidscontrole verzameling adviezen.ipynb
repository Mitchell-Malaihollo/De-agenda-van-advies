# %%
import os
import json

# %%
with open("../data/GR_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    gr = json.load(f)

with open("../data/AM_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    am = json.load(f)

with open("../data/RLI_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    rli = json.load(f)

with open("../data/ROB_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    rob = json.load(f)

with open("../data/Kiesraad_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    kiesraad = json.load(f)

with open("../data/MER_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    mer = json.load(f)


print("Aantal items in JSON bestand (AM):       " + str(len(am)))
print("Aantal items in JSON bestand (ROB):      " + str(len(rob)))
print("Aantal items in JSON bestand (RLI):      " + str(len(rli)))
print("Aantal items in JSON bestand (KIESRAAD): " + str(len(kiesraad)))
print("Aantal items in JSON bestand (MER):      " + str(len(mer)))
print("Aantal items in JSON bestand (GR):       " + str(len(gr)))
# Out:
# Aantal items in JSON bestand (AM):       44
# Aantal items in JSON bestand (ROB):      27
# Aantal items in JSON bestand (RLI):      30
# Aantal items in JSON bestand (KIESRAAD): 59
# Aantal items in JSON bestand (MER):      546
# Aantal items in JSON bestand (GR):       188

# %%
rli_missende_description = 0 
rli_missende_datum = 0
rli_missende_titel = 0
rli_missend_iets = 0
rli_mist_alles = 0

rob_missende_description = 0 
rob_missende_datum = 0
rob_missende_titel = 0
rob_missend_iets = 0
rob_mist_alles = 0

mer_missende_description = 0 
mer_missende_datum = 0
mer_missende_titel = 0
mer_missend_iets = 0
mer_mist_alles = 0

am_missende_description = 0 
am_missende_datum = 0
am_missende_titel = 0
am_missend_iets = 0
am_mist_alles = 0

kiesraad_missende_description = 0 
kiesraad_missende_datum = 0
kiesraad_missende_titel = 0
kiesraad_missend_iets = 0
kiesraad_mist_alles = 0

gr_missende_description = 0 
gr_missende_datum = 0
gr_missende_titel = 0
gr_missend_iets = 0
gr_mist_alles = 0

for data in rli:
    mist_iets = False
    mist_iets_num = 0
    desc = data.get("dc_description")
    datum = data.get("foi_publishedDate")
    titel = data.get("dc_title")
    if desc == '':
        rli_missende_datum += 1
        mist_iets = True
        mist_iets_num += 1
    if datum == '':
        rli_missende_description += 1
        mist_iets = True
        mist_iets_num += 1
    if titel == '':
        rli_missende_titel += 1
        mist_iets = True
        mist_iets_num += 1
    if mist_iets == True:
        rli_missend_iets += 1
    if mist_iets_num == 3:
        rli_mist_alles += 1 

print("RLI:")
print("mist iets: " + str(rli_missend_iets))
print("mist desc: " + str(rli_missende_description))
print("mist titel: " + str(rli_missende_titel))
print("mist datum: " + str(rli_missende_datum))
print("mist alles: " + str(rli_mist_alles))
print('------')

for data in rob:
    mist_iets = False
    mist_iets_num = 0
    desc = data.get("dc_description")
    datum = data.get("foi_publishedDate")
    titel = data.get("dc_title")
    if desc == '':
        rob_missende_datum += 1
        mist_iets = True
        mist_iets_num += 1
    if datum == '':
        rob_missende_description += 1
        mist_iets = True
        mist_iets_num += 1
    if titel == '':
        rob_missende_titel += 1
        mist_iets = True
        mist_iets_num += 1
    if mist_iets == True:
        rob_missend_iets += 1
    if mist_iets_num == 3:
        rob_mist_alles += 1 

print("ROB:")
print("mist iets: " + str(rob_missend_iets))
print("mist desc: " + str(rob_missende_description))
print("mist titel: " + str(rob_missende_titel))
print("mist datum: " + str(rob_missende_datum))
print("mist alles: " + str(rob_mist_alles))
print('------')

for data in mer:
    mist_iets = False
    mist_iets_num = 0
    desc = data.get("dc_description")
    datum = data.get("foi_publishedDate")
    titel = data.get("dc_title")
    if desc == '':
        mer_missende_datum += 1
        mist_iets = True
        mist_iets_num += 1
    if datum == '':
        mer_missende_description += 1
        mist_iets = True
        mist_iets_num += 1
    if titel == '':
        mer_missende_titel += 1
        mist_iets = True
        mist_iets_num += 1
    if mist_iets == True:
        mer_missend_iets += 1
    if mist_iets_num == 3:
        mer_mist_alles += 1 

print("MER:")
print("mist iets: " + str(mer_missend_iets))
print("mist desc: " + str(mer_missende_description))
print("mist titel: " + str(mer_missende_titel))
print("mist datum: " + str(mer_missende_datum))
print("mist alles: " + str(mer_mist_alles))
print('------')

for data in kiesraad:
    mist_iets = False
    mist_iets_num = 0
    desc = data.get("dc_description")
    datum = data.get("foi_publishedDate")
    titel = data.get("dc_title")
    if desc == '':
        kiesraad_missende_datum += 1
        mist_iets = True
        mist_iets_num += 1
    if datum == '':
        kiesraad_missende_description += 1
        mist_iets = True
        mist_iets_num += 1
    if titel == '':
        kiesraad_missende_titel += 1
        mist_iets = True
        mist_iets_num += 1
    if mist_iets == True:
        kiesraad_missend_iets += 1
    if mist_iets_num == 3:
        kiesraad_mist_alles += 1 

print("KIESRAAD:")
print("mist iets: " + str(kiesraad_missend_iets))
print("mist desc: " + str(kiesraad_missende_description))
print("mist titel: " + str(kiesraad_missende_titel))
print("mist datum: " + str(kiesraad_missende_datum))
print("mist alles: " + str(kiesraad_mist_alles))
print('------')

for data in am:
    mist_iets = False
    mist_iets_num = 0
    desc = data.get("dc_description")
    datum = data.get("foi_publishedDate")
    titel = data.get("dc_title")
    if desc == '':
        am_missende_datum += 1
        mist_iets = True
        mist_iets_num += 1
    if datum == '':
        am_missende_description += 1
        mist_iets = True
        mist_iets_num += 1
    if titel == '':
        am_missende_titel += 1
        mist_iets = True
        mist_iets_num += 1
    if mist_iets == True:
        am_missend_iets += 1
    if mist_iets_num == 3:
        am_mist_alles += 1 

print("AM:")
print("mist iets: " + str(am_missend_iets))
print("mist desc: " + str(am_missende_description))
print("mist titel: " + str(am_missende_titel))
print("mist datum: " + str(am_missende_datum))
print("mist alles: " + str(am_mist_alles))
print('------')

for data in gr:
    mist_iets = False
    desc = data.get("dc_description")
    datum = data.get("foi_publishedDate")
    titel = data.get("dc_title")
    if datum == '':
        gr_missende_datum += 1
        mist_iets = True
        mist_iets_num = 0
        mist_iets_num += 1
    if desc == '':
        gr_missende_description += 1
        mist_iets = True
        mist_iets_num += 1
    if titel == '':
        gr_missende_titel += 1
        mist_iets = True
        mist_iets_num += 1
    if mist_iets == True:
        gr_missend_iets += 1
    if mist_iets_num == 3:
        gr_mist_alles += 1

print("GR:")
print("mist iets: " + str(gr_missend_iets))
print("mist desc: " + str(gr_missende_description))
print("mist titel: " + str(gr_missende_titel))
print("mist datum: " + str(gr_missende_datum))
print("mist alles: " + str(gr_mist_alles))
print('------')

totaal_missende_description = rob_missende_description + rli_missende_description + mer_missende_description + kiesraad_missende_description + am_missende_description + gr_missende_description
totaal_missende_datum = rob_missende_datum + mer_missende_datum + am_missende_datum + gr_missende_datum + kiesraad_missende_datum + rli_missende_datum
totaal_missende_titel = rob_missende_titel + mer_missende_titel + am_missende_titel + gr_missende_titel + kiesraad_missende_titel + rli_missende_titel
totaal_missend_iets = rob_missend_iets + mer_missend_iets + am_missend_iets + gr_missend_iets + kiesraad_missend_iets + rli_missend_iets
totaal_missend_alles = gr_mist_alles + rob_mist_alles + rli_mist_alles + am_mist_alles + kiesraad_mist_alles + mer_mist_alles

print("Totaal:")
print("mist iets: " + str(totaal_missend_iets))
print("mist desc: " + str(totaal_missende_description))
print("mist titel: " + str(totaal_missende_titel))
print("mist datum: " + str(totaal_missende_datum))
print("mist alles: " + str(totaal_missend_alles))
# Out:
# RLI:
# mist iets: 4
# mist desc: 4
# mist titel: 1
# mist datum: 1
# mist alles: 1
# ------
# ROB:
# mist iets: 0
# mist desc: 0
# mist titel: 0
# mist datum: 0
# mist alles: 0
# ------
# MER:
# mist iets: 6
# mist desc: 6
# mist titel: 3
# mist datum: 3
# mist alles: 3
# ------
# KIESRAAD:
# mist iets: 2
# mist desc: 2
# mist titel: 1
# mist datum: 2
# mist alles: 1
# ------
# AM:
# mist iets: 0
# mist desc: 0
# mist titel: 0
# mist datum: 0
# mist alles: 0
# ------
# GR:
# mist iets: 32
# mist desc: 0
# mist titel: 0
# mist datum: 32
# mist alles: 0
# ------
# Totaal:
# mist iets: 44
# mist desc: 12
# mist titel: 5
# mist datum: 38
# mist alles: 5
