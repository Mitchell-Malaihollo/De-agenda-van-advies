# %% [markdown]
# # RO RE RM evaluatie
#
# Zoekmethode1 = Handmatig OpenTK
#
# Zoekmethode2 = LLM Thinking
#
# Zoekmethode3 = LLM 5.1 API
#
# Zoekmethode4 = Handmatig Google
#
# duplicaten, in de vorm van dezelfde documenten op verschillende plekken, zijn geteld als correcte resultaten.

# %%
import json

with open(r"..\Data\auto_doc_retrieval_zoekmethode1.json", "r", encoding="utf-8") as f:
    d1 = json.load(f)
with open(r"..\Data\auto_doc_retrieval_zoekmethode2.json", "r", encoding="utf-8") as f:
    d2 = json.load(f)
with open(r"..\Data\auto_doc_retrieval_zoekmethode3.json", "r", encoding="utf-8") as f:
    d3 = json.load(f)
with open(r"..\Data\auto_doc_retrieval_zoekmethode4.json", "r", encoding="utf-8") as f:
    d4 = json.load(f)

globals().update(d1)
globals().update(d2)
globals().update(d3)
globals().update(d4)

# %% [markdown]
# # id 1

# %%
print("ground truth: " + str(ground_truth_id1))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id1))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id1))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id1))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id1))


print(str(len(ground_truth_id1)))
print(str(len(zoekmethode1_id1)))
print(str(len(zoekmethode2_id1)))
print(str(len(zoekmethode3_id1)))
print(str(len(zoekmethode4_id1)))
# Out:
# zoekmethode 1: {'Medische misinformatie ontworteld. Luisteren naar zorgen en kweken van gegrond vertrouwen': 'https://www.tweedekamer.nl/kamerstukken/kamervragen/detail?id=2025D28810&did=2025D28810', 'Veilingsregeling 3,5 GHzband': 'https://www.tweedekamer.nl/kamerstukken/kamervragen/detail?id=2023D50842&did=2023D50842', 'Memorie van toelichting': 'https://www.tweedekamer.nl/kamerstukken/kamervragen/detail?id=2021D24713&did=2021D24713', 'Lijst van vragen en antwoorden over onderzoeken in het kader van de Rijkscoördinatieregeling voor de radar in Herwijnen': 'https://www.tweedekamer.nl/kamerstukken/kamervragen/detail?id=2020D46568&did=2020D46568', 'Verslag van een notaoverleg, gehouden op 1 februari 2021, over preventie': 'https://www.tweedekamer.nl/kamerstukken/kamervragen/detail?id=2021D06497&did=2021D06497', 'Preventie (medische-, leefstijl- en infectiepreventie)/verslavingszorg/drugsbeleid Notaoverleg': 'https://debatdirect.tweedekamer.nl/2021-02-01/zorg-gezondheid/thorbeckezaal/p
# ...

# %% [markdown]
# ### zoekmethode 1
# * GTO: 5
# * GTE: 32
# * GTM: 3
#
# ### zoekmethode 2
# * GTO: 9
# * GTE: 6
# * GTM: 0
#
# ### zoekmethode 3
# * GTO: 2
# * * 1 duplicaat die is meegerekend
# * GTE: 2
# * GTM: 6
#
# ### zoekmethode 4
# * GTO: 3
# * GTE: 4
# * GTM: 4

# %% [markdown]
# # id 2

# %%
print("ground truth: " + str(ground_truth_id2))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id2))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id2))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id2))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id2))

print(str(len(ground_truth_id2)))
print(str(len(zoekmethode1_id2)))
print(str(len(zoekmethode2_id2)))
print(str(len(zoekmethode3_id2)))
print(str(len(zoekmethode4_id2)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 4
# * GTE: 15
# * GTM: 4
#
# ### zoekmethode 2
# * GTO: 5
# * GTE: 6
# * GTM: 3
#
# ### zoekmethode 3
# * GTO: 0
# * GTE: 2
# * GTM: 8
#
# ### zoekmethode 4
# * GTO: 4
# * GTE: 3
# * GTM: 5

# %% [markdown]
# # id 3

# %%
print("ground truth: " + str(ground_truth_id3))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id3))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id3))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id3))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id3))

print(str(len(ground_truth_id3)))
print(str(len(zoekmethode1_id3)))
print(str(len(zoekmethode2_id3)))
print(str(len(zoekmethode3_id3)))
print(str(len(zoekmethode4_id3)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 1
# * GTE: 0
# * GTM: 1
#
# ### zoekmethode 2
# * GTO: 7
# * * 5 duplicaten die zijn meegeteld
# * GTE: 6
# * GTM: 0
#
# ### zoekmethode 3
# * GTO: 3
# * GTE: 0
# * GTM: 1
#
# ### zoekmethode 4
# * GTO: 2
# * GTE: 8
# * GTM: 0

# %% [markdown]
# # id 4

# %%
print("ground truth: " + str(ground_truth_id4))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id4))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id4))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id4))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id4))

print(str(len(ground_truth_id4)))
print(str(len(zoekmethode1_id4)))
print(str(len(zoekmethode2_id4)))
print(str(len(zoekmethode4_id4)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 0
# * GTE: 0
# * GTM: 4
#
# ### zoekmethode 2
# * GTO: 0
# * GTE: 12
# * GTM: 4
#
# ### zoekmethode 3
# * GTO: 0
# * GTE: 0
# * GTM: 4
#
# ### zoekmethode 4
# * GTO: 2
# * GTE: 1
# * GTM: 2

# %% [markdown]
# # id 5

# %%
print("ground truth: " + str(ground_truth_id5))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id5))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id5))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id5))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id5))

print(str(len(ground_truth_id5)))
print(str(len(zoekmethode1_id5)))
print(str(len(zoekmethode2_id5)))
print(str(len(zoekmethode3_id5)))
print(str(len(zoekmethode4_id5)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 1
# * GTE: 30
# * GTM: 3
#
# ### zoekmethode 2
# * GTO: 5
# * * 2 duplicaten die zijn meegeteld
# * GTE: 7
# * GTM: 1
#
# ### zoekmethode 3
# * GTO: 2
# * * 1 duplicaat is meegeteld
# * GTE: 3
# * GTM: 3
#
# ### zoekmethode 4
# * GTO: 2
# * GTE: 3
# * GTM: 2

# %% [markdown]
# # id 6

# %%
print("ground truth: " + str(ground_truth_id6))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id6))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id6))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id6))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id6))

print(str(len(ground_truth_id6)))
print(str(len(zoekmethode1_id6)))
print(str(len(zoekmethode2_id6)))
print(str(len(zoekmethode3_id6)))
print(str(len(zoekmethode4_id6)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 1
# * GTE: 15
# * GTM: 2
#
# ### zoekmethode 2
# * GTO: 3
# * * 1 duplicaat is meegeteld
# * GTE: 12
# * GTM: 1
#
# ### zoekmethode 3
# * GTO: 1
# * GTE: 1
# * GTM: 2
#
# ### zoekmethode 4
# * GTO: 3
# * GTE: 4
# * GTM: 1

# %% [markdown]
# # id 7

# %%
print("ground truth: " + str(ground_truth_id7))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id7))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id7))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id7))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id7))

print(str(len(ground_truth_id7)))
print(str(len(zoekmethode1_id7)))
print(str(len(zoekmethode2_id7)))
print(str(len(zoekmethode4_id7)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 1
# * GTE: 19
# * GTM: 3
#
# ### zoekmethode 2
# * GTO: 4
# * * 2 duplicaten zijn meegeteld
# * GTE: 11
# * GTM: 2
#
# ### zoekmethode 3
# * GTO: 1
# * GTE: 0
# * GTM: 3
#
# ### zoekmethode 4
# * GTO: 2
# * GTE: 6
# * GTM: 0

# %% [markdown]
# # id 8

# %%
print("ground truth: " + str(ground_truth_id8))
print("---")
print("zoekmethode 1: " + str(zoekmethode1_id8))
print("---")
print("zoekmethode 2: " + str(zoekmethode2_id8))
print("---")
print("zoekmethode 3: " + str(zoekmethode3_id8))
print("---")
print("zoekmethode 4: " + str(zoekmethode4_id8))

print(str(len(ground_truth_id8)))
print(str(len(zoekmethode1_id8)))
print(str(len(zoekmethode2_id8)))
print(str(len(zoekmethode3_id8)))
print(str(len(zoekmethode4_id8)))

# %% [markdown]
# ### zoekmethode 1
# * GTO: 0
# * GTE: 11
# * GTM: 6
#
# ### zoekmethode 2
# * GTO: 2
# * GTE: 6
# * GTM: 4
#
# ### zoekmethode 3
# * GTO: 1
# * GTE: 3
# * GTM: 5
#
# ### zoekmethode 4
# * GTO: 2
# * GTE: 5
# * GTM: 4

# %% [markdown]
# # TOTAAL TOTAAL TOTAAL TOTAAL TOTAAL TOTAAL

# %% [markdown]
# ### totaal zoekmethode 1
# * GTO: 13
# * GTE: 125
# * GTM: 26
#
# ### totaal zoekmethode 2
# * GTO: 35
# * GTE: 66
# * GTM: 15
#
# ### totaal zoekmethode 3
# * GTO: 10
# * GTE: 11
# * GTM: 32
#
# ### totaal zoekmethode 4
# * GTO: 20
# * GTE: 34
# * GTM: 18

# %%
totaal_methode1_gto = 13
totaal_methode1_gte = 125
totaal_methode1_gtm = 26
totaal_methode2_gto = 35
totaal_methode2_gte = 66
totaal_methode2_gtm = 15
totaal_methode3_gto = 10
totaal_methode3_gte = 11
totaal_methode3_gtm = 32
totaal_methode4_gto = 20
totaal_methode4_gte = 34
totaal_methode4_gtm = 18

prec_methode1 = totaal_methode1_gto / (totaal_methode1_gto + totaal_methode1_gte)
rec_methode1 = totaal_methode1_gto / (totaal_methode1_gto + totaal_methode1_gtm)
f1_methode1 = (prec_methode1 * rec_methode1) / (prec_methode1 + rec_methode1)

prec_methode2 = totaal_methode2_gto / (totaal_methode2_gto + totaal_methode2_gte)
rec_methode2 = totaal_methode2_gto / (totaal_methode2_gto + totaal_methode2_gtm)
f1_methode2 = (prec_methode2 * rec_methode2) / (prec_methode2 + rec_methode2)

prec_methode3 = totaal_methode3_gto / (totaal_methode3_gto + totaal_methode3_gte)
rec_methode3 = totaal_methode3_gto / (totaal_methode3_gto + totaal_methode3_gtm)
f1_methode3 = (prec_methode3 * rec_methode3) / (prec_methode3 + rec_methode3)

prec_methode4 = totaal_methode4_gto / (totaal_methode4_gto + totaal_methode4_gte)
rec_methode4 = totaal_methode4_gto / (totaal_methode4_gto + totaal_methode4_gtm)
f1_methode4 = (prec_methode4 * rec_methode4) / (prec_methode4 + rec_methode4)

print("zoekmethode 1")
print(prec_methode1)
print(rec_methode1)
print(f1_methode1)
print("---")
print("zoekmethode 2")
print(prec_methode2)
print(rec_methode2)
print(f1_methode2)
print("---")
print("zoekmethode 3")
print(prec_methode3)
print(rec_methode3)
print(f1_methode3)
print("---")
print("zoekmethode 4")
print(prec_methode4)
print(rec_methode4)
print(f1_methode4)
print("---")
# Out:
# zoekmethode 1
# 0.09420289855072464
# 0.3333333333333333
# 0.07344632768361582
# ---
# zoekmethode 2
# 0.3465346534653465
# 0.7
# 0.23178807947019864
# ---
# zoekmethode 3
# 0.47619047619047616
# 0.23809523809523808
# 0.15873015873015875
# ---
# zoekmethode 4
# 0.37037037037037035
# 0.5263157894736842
# 0.21739130434782608
# ---
