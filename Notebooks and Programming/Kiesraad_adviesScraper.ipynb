# %% [markdown]
# # Kiesraad_AdviesScraper
#
# Doel: Kiesraad adviezen uitgebracht vanaf 2019 tot en met 2024 verzamelen.
#
# Toepassing: Bachelor-scriptie Informatiekunde, Universiteit van Amsterdam
#
# Contact: mitchell.malaihollo@student.uva.nl
#
# Metadata Formatering volgens de [Woogle metadata specificatie](https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema)

# %%
import time
from urllib.parse import urljoin
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from openai import OpenAI
from dotenv import load_dotenv
import json
from selenium.common.exceptions import NoSuchElementException
from urllib.parse import urljoin, urlparse

# %%
# De Kiesraad volgt een andere paginatie methode als het AM en de ROB dus hier moet de laatste pagina handmatig worden toegevoegd
laatstepagina = 40

HREF_ID_WOORDEN = {"briefadvies", "wetsadvies", "advies", "adviesrapport", "adviesproject"}
ID_WOORDEN = {"briefadvies", "advies:", "advies", "adviesrapport", "adviesproject", "wetsadvies", "adviesvraag"}

USER_AGENT = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) "
    "Gecko/20100101 Firefox/124.0 "
    "AdviescollegeScraper (+mailto:14605120@student.uva.nl; "
    "voor BSc-scriptie Informatiekunde UvA; "
    "doel: informatie inwinnen over verschillende adviescolleges)"
)

BASE_URL = (
    "https://www.kiesraad.nl/adviezen-en-publicaties?"
    "startdatum=01-01-2019"
    "&einddatum=31-12-2024"
)

env_path = r"C:\Users\31633\OneDrive\Bureaublad\OpenAI_API_Key.env"  
load_dotenv(env_path)
api_key = os.getenv("OPENAI_API_KEY")
print("Key geladen:", api_key is not None)
# Out:
# Key geladen: True

# %%
import re

def beginSelenium():
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument(f"user-agent={USER_AGENT}")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )
    return driver

driver = beginSelenium()
driver.get(BASE_URL)
time.sleep(2)
print("Maximaal aantal pagina's om te controleren: " + str(laatstepagina))
print("-----------------------")

adviesURLS = []
for paginaNummer in range(1, laatstepagina + 1):
    if paginaNummer == 1:
        BASE_paginaURL = BASE_URL
    else:
        BASE_paginaURL = f"{BASE_URL}&pagina={paginaNummer}"

    print("Pagina: " + str(paginaNummer))
    print(BASE_paginaURL)

    driver.get(BASE_paginaURL)
    time.sleep(2)

    li_items = driver.find_elements(
        By.CSS_SELECTOR,
        "ol.common.results li.results__item"
    )

    for li in li_items:
        try:
            a_tag = li.find_element(By.CSS_SELECTOR, "a.publication")
        except NoSuchElementException:
            continue
        
        href = a_tag.get_attribute("href")
        if href.startswith("/"):
            href = BASE + href

        # titel
        title_element = li.find_element(By.CSS_SELECTOR, "h3")
        title_text = title_element.text.strip().lower()

        # metadata
        meta_p = li.find_element(By.CSS_SELECTOR, "p.meta")
        meta_text = meta_p.text.strip().lower()
        doc_type = meta_text.split("|")[0].strip()

        # eerste woord van de href
        href_delen = urlparse(href).path
        href_deel = href_delen.strip("/").split("/")[-1]
        eerste_woord = href_deel.split("-")[0]

        # eerste woord van de titel
        eerste_woord_titel = title_text.split()[0] if title_text else ""

        # metadata check
        if "advies" in doc_type:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue

        # href eerste woord check
        if eerste_woord in HREF_ID_WOORDEN:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue

        # titel check
        if eerste_woord_titel in ID_WOORDEN:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue
    time.sleep(5)

    print("-------------------")
# Out:
# Maximaal aantal pagina's om te controleren: 40
# -----------------------
# Pagina: 1
# https://www.kiesraad.nl/adviezen-en-publicaties?startdatum=01-01-2019&einddatum=31-12-2
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/oktober/advies-grondwetsherziening-kiescollege-buitenland/advies-grondwetsherziening-kiescollege-buitenland
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/1970/12/02/advies-grondwetsherziening-kiescollege-buitenland-kopie
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/oktober/advies-conceptwetsvoorstel-3e-versie-aanpassing-procedure-vaststelling-verkiezingsuitslag/advies-conceptwetsvoorstel-3e-versie-aanpassing-procedure-vaststelling-verkiezingsuitslag
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/oktober/advies-over-het-conceptwetsvoorstel-tijdelijke-experimentenwet-nieuwe-stembiljetten/advies-over-wetsvoorstel-tijdelijke-experimentenwet-nieuwe-stembiljetten
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/augustus/evaluatieadvies-europees-parlement-en-eerste-kamer-2019/evaluatieadvies-europees-parlement-en-eerste-kamer-2019
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/adviezen_mei_2019/evaluatie-advies-ps-ws-kc-2019/advies-evaluatie-verkiezingen-provinciale-staten-waterschappen-en-kiescolleges-2019
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/adviezen_mei_2019/tweede-advies-over-conceptwetsvoorstel-aanpassing-procedure-vaststelling-verkiezingsuitslag/tweede-advies-over-conceptwetsvoorstel-aanpassing-procedure-vaststelling-verkiezingsuitslag
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/2/11/advies-wijziging-regeling-tijdelijke-vervanging-leden-vertegenwoordigende-organen
# https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/januari/14/advies-over-ontwerpregeling-vaststelling-model-proces-verbaal-i.v.m.-mogelike-toewijzing-extra-zetels-ep
#
# Totaal aantal unieke adviezen-links: 59

# %%
res = []
for url in adviesURLS:
    client = OpenAI()

    prompt = f"""
    Lees dit document: {url}

    Vul de onderstaande JSON in volgens https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema:

    {{
        "dc_title": "",
        "foi_publishedDate": "",
        "dc_description": ""
    }}

    Regels:
    - Alleen écht gevonden info invullen.
    - Max 100 woorden in dc_description.
    - Ontbreekt iets? dan "" laten.
    - datum in jjjj-mm-dd
    - Output = alleen geldige JSON niks anders.
    """
    response = client.responses.create(
        model="gpt-5.1",
        input=prompt,
        tools=[{"type": "web_search"}],
        max_output_tokens=800,
    )
    
    json_str = response.output_text.strip()

    try:
        data = json.loads(json_str)
    except json.JSONDecodeError:
        print("Kon JSON niet parsen voor URL:", url)
        print("Ruwe output was:\n", json_str)
        continue

    data["dc_source"] = url
    data["dc_publisher"] = "zb000174"
    data["dc_type"] = "2e"
        
    res.append(data)
    
    print(json.dumps(data, ensure_ascii=False, indent=2))
    
    time.sleep(12)

with open("Kiesraad_adviesScraper_data1.json", "w", encoding="utf-8") as f:
    json.dump(res, f, ensure_ascii=False, indent=2)
    
print("\nAlle JSON-data opgeslagen in Kiesraad_adviesScraper_data1.json")
# Out:
# {
#   "dc_title": "Aanvullend advies over het vereenvoudigen van de processen-verbaal en corrigenda",
#   "foi_publishedDate": "2024-12-19",
#   "dc_description": "De Kiesraad doet verbetervoorstellen voor 12 modellen die worden gebruikt door stembureaus, gemeentelijk stembureaus, hoofdstembureaus en centraal stembureaus. Het gaat om wijzigingen in samenvoegen van modellen en in vormgeving, opbouw en structuur. Dit advies volgt op het advies van 30 oktober 2023 over tekstuele aanpassingen in de modellen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2024/12/19/aanvullend-advies-over-het-vereenvoudigen-van-de-processen-verbaal-en-corrigenda",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Evaluatie Tijdelijke experimentenwet nieuwe stembiljetten",
#   "foi_publishedDate": "2024-11-12",
#   "dc_description": "Tijdens de Europees Parlementsverkiezing van 6 juni 2024 is in vijf gemeenten geëxperimenteerd met een kleiner stembiljet op basis van de Tijdelijke experimentenwet nieuwe stembiljetten. De Kiesraad bezocht deze gemeenten, onderzocht de processen-verbaal van stembureaus en gemeentelijke stembureaus en liet zich informeren over onderzoeken onder kiezers en stembureauleden. De bevindingen zijn vastgelegd in een briefadvies aan de Minister van Binnenlandse Zaken en Koninkrijksrelaties.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2024/11/12/advies-evaluatie-tijdelijke-experimentenwet-nieuwe-stembiljetten",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Evaluatieadvies Europees Parlementsverkiezing 2024: Voorspoedig verlopen verkiezing",
#   "foi_publishedDate": "2024-10-01",
#   "dc_description": "De Kiesraad concludeert dat de Europees Parlementsverkiezing 2024 voorspoedig is verlopen en heeft geleid tot een betrouwbare uitslag. De uitvoering van de nieuwe procedure voor de vaststelling van de verkiezingsuitslagen (NPVV) verloopt steeds beter door ervaringen bij verkiezingen in 2023 en doorgevoerde verbeteringen na eerdere evaluaties. Tegelijk blijven de uitvoeringslasten groot en is blijvende aandacht nodig voor de uitvoerbaarheid van de verkiezingen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2024/10/01/evaluatieadvies-ep-2024-voorspoedig-verlopen-verkiezing",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Wetsvoorstel met één stem meer keus",
#   "foi_publishedDate": "2024-04-10",
#   "dc_description": "De Kiesraad adviseert over invoering van een nieuw kiesstelsel waarin kiezers kunnen kiezen tussen een lijststem op een politieke groepering of een kandidaatsstem op een individuele kandidaat. Dit moet de band tussen kiezers en gekozenen versterken, met behoud van toegankelijkheid en diversiteit van de democratie. Het advies reageert op het aangepaste wetsvoorstel Met één stem meer keus.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2024/04/10/advies-wetsvoorstel-met-een-stem-meer-keus",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Wet verlenen van bijstand bij het stemmen in een stemhokje",
#   "foi_publishedDate": "2024-04-04",
#   "dc_description": "Advies van de Kiesraad over een wetsvoorstel van de minister van Binnenlandse Zaken en Koninkrijksrelaties om alle kiezers die daarom vragen, waaronder mensen met een lichamelijke beperking, hulp te kunnen bieden in het stemhokje door stembureauleden, zodat meer mensen zelfstandig kunnen stemmen en verkiezingen toegankelijker worden.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2024/04/04/advies-wet-verlenen-van-bijstand-bij-het-stemmen-in-een-stemhokje",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Evaluatieadvies Tweede Kamerverkiezing 2023",
#   "foi_publishedDate": "2024-03-13",
#   "dc_description": "De Kiesraad constateert dat de Tweede Kamerverkiezing van 22 november 2023 in het algemeen goed is verlopen en dat de uitslag betrouwbaar is. Ook blijkt dat de nieuwe procedure voor de vaststelling van verkiezingsuitslagen structureel extra capaciteit en expertise vraagt bij alle uitvoerenden. Deze punten worden besproken in het evaluatieadvies over de Tweede Kamerverkiezing 2023.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2024/03/13/evaluatie-van-de-tweede-kamerverkiezing-2023",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Tijdelijke experimentenregeling nieuwe stembiljetten",
#   "foi_publishedDate": "2023-12-19",
#   "dc_description": "In het parlement is de Tijdelijke experimentenwet nieuwe stembiljetten aangenomen. De minister van Binnenlandse Zaken en Koninkrijksrelaties bereidt een Tijdelijke experimentenregeling nieuwe stembiljetten voor en heeft hierover advies gevraagd aan de Kiesraad, die positief heeft geadviseerd over deze concrete stap naar een kleiner stembiljet.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2023
",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2022/4/14/advies-besluit-kiescollege-niet-ingezetenen-en-wijziging-kiesbesluit",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies wijziging Kiesbesluit",
#   "foi_publishedDate": "2022-03-31",
#   "dc_description": "De minister van BZK is van plan het Kiesbesluit te wijzigen vanwege een nieuwe procedure voor de vaststelling van verkiezingsuitslagen en de invoering van een nieuw stembiljet voor kiezers buiten Nederland. De Kiesraad doet voorstellen voor technische eisen aan logo’s van politieke partijen, het vermijden van overlap tussen Kieswet en Kiesbesluit, verduidelijking bij schorsing van het telproces, toevoeging van eisen aan digitale telbestanden en het vervroegen van het bezorgmoment van kiezersinformatie.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2022/3/31/index",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over de uitvoeringswet kiescollege niet-ingezetenen",
#   "foi_publishedDate": "2021-11-25",
#   "dc_description": "De uitvoeringswet kiescollege niet-ingezetenen regelt dat kiezers in het buitenland invloed hebben op de samenstelling van de Eerste Kamer. Nu hebben zij alleen invloed op de samenstelling van de Tweede Kamer en het Europees Parlement. De Kiesraad kan instemmen met dit conceptwetsvoorstel, maar vindt dat het op een aantal onderdelen moet worden aangepast.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/11/25/advies-over-de-uitvoeringswet-kiescollege-niet-ingezetenen",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Kiesraad: beoordeling geldigheid stemmingen",
#   "foi_publishedDate": "2021-10-12",
#   "dc_description": "Webpagina van de Kiesraad met toegang tot het adviesdocument ‘Advies Kiesraad: beoordeling geldigheid stemmingen’, gepubliceerd op 12-10-2021, over de beoordeling van de geldigheid van stemmingen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/10/12/advies-beoordeling-geldigheid-stemmingen",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies experimentenwet assistentie bij stemmen",
#   "foi_publishedDate": "2021-09-24",
#   "dc_description": "De experimentenwet assistentie bij stemmen maakt het mogelijk om de komende vijf jaar te experimenteren met het verlenen van assistentie in het stemhokje aan alle kiezers. Nu is dat alleen mogelijk voor kiezers met een lichamelijke beperking. De Kiesraad waardeert het dat er geëxperimenteerd gaat worden met hulp bij het stemmen, omdat dit de politieke participatie van personen met een (lichte) verstandelijke beperking vergroot.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/09/24/advies-experimentenwet-assistentie-bij-stemmen",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over de afschaling en aanpassing van de Tijdelijke regeling verkiezingen covid-19",
#   "foi_publishedDate": "2021-09-17",
#   "dc_description": "De Kiesraad stemt in met aanpassingen van de Tijdelijke regeling verkiezingen covid-19. Deze aanpassingen zijn nodig met het oog op de herindelingsverkiezingen van 24 november. Zo is het straks niet meer nodig om een mondneusmasker in het stemlokaal te dragen. Ook is het niet meer verplicht de handen te desinfecteren voor het stemmen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/09/17/advies-over-de-afschaling-en-aanpassing-van-de-tijdelijke-regeling-verkiezingen-covid-19",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over experimentbesluit nieuw stembiljet",
#   "foi_publishedDate": "2021-08-10",
#   "dc_description": "Advies van de Kiesraad over het Experimentbesluit nieuw stembiljet, gepubliceerd op 10-08-2021, waarin de raad zijn oordeel geeft over het besluit om met een nieuw stembiljet te experimenteren.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/08/10/advies-over-experimentbesluit-nieuw-stembiljet",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over conceptwetsvoorstel programmatuur verkiezingsuitslagen",
#   "foi_publishedDate": "2021-07-27",
#   "dc_description": "De Kiesraad adviseert positief over het conceptwetsvoorstel programmatuur verkiezingsuitslagen. Het wetsvoorstel maakt de Kiesraad verantwoordelijk voor het beheer en de beveiliging van de programmatuur voor de berekening en vaststelling van verkiezingsuitslagen en stelt het gebruik van deze programmatuur verplicht.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/07/27/advies-over-wetsvoorstel-programmatuur-verkiezingsuitslagen",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over de afschaling en aanpassing van de Tijdelijke wet verkiezingen COVID-19",
#   "foi_publishedDate": "2021-06-24",
#   "dc_description": "Advies van de Kiesraad over de afschaling en aanpassing van de Tijdelijke wet verkiezingen COVID-19. De Kiesraad stemt in met het niet meer aanbieden van briefstemmen, omdat het verspreidingsrisico van het covid-19-virus is afgenomen. Ook vindt de Kiesraad het positief dat het aantal volmachten wordt teruggebracht van drie naar twee en kan de raad zich vinden in de flexibele afschaling van hygiënevoorschriften voor kiezers en stembureauleden.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/06/24/advies-over-de-afschaling-en-aanpassing-van-de-tijdelijke-wet-verkiezingen-covid-19",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over de verlenging van de Tijdelijke experimentenwet stembiljetten en centrale stemopneming",
#   "foi_publishedDate": "2021-06-04",
#   "dc_description": "De Kiesraad adviseert positief over verlenging van de Tijdelijke experimentenwet stembiljetten en centrale stemopneming tot 1 januari 2024. Hiermee blijven experimenten met andere stembiljetmodellen en centrale stemopneming mogelijk en wordt voorkomen dat kiezers buiten Nederland het stembiljet weer uitsluitend per post ontvangen. Gemeenten kunnen door de verlenging gebruik blijven maken van centraal tellen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/06/04/advies-over-de-verlenging-van-de-tijdelijke-experimentenwet-stembiljetten-en-centrale-stemopneming",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over de evaluatie van de Tweede Kamerverkiezing van 2021",
#   "foi_publishedDate": "2021-05-19",
#   "dc_description": "Investeringen in het verkiezingsproces zijn noodzakelijk en dienen prioriteit te krijgen van een nieuw kabinet. In dit evaluatieadvies over de Tweede Kamerverkiezing van 17 maart stelt de Kiesraad dat het vertrouwen in het verkiezingsproces ook in de toekomst moet worden gewaarborgd. Daarvoor zijn aanpassingen nodig, zoals verbetering van het proces van kandidaatstelling tot en met de vaststelling van de uitslag, grotere transparantie en meer mogelijkheden om fouten in het telproces te onderzoeken en te herstellen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/05/19/advies-over-de-evaluatie-van-de-tweede-kamerverkiezing-van-2021",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Spoedadvies Kiesraad over wijziging instructie vooropening briefstemmen",
#   "foi_publishedDate": "2021-03-16",
#   "dc_description": "Deze pagina op Kiesraad.nl bevat het spoedadvies van de Kiesraad over de wijziging van de instructie vooropening van briefstemmen, inclusief een downloadbare PDF met het adviesdocument.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021/03/15/advies-briefstemmen",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over het wetsvoorstel Burgerforum kiesstelsel",
#   "foi_publishedDate": "2021-01-29",
#   "dc_description": "De Kiesraad staat positief tegenover een nieuw kiesstelsel waarbij de kiezer kan stemmen op de lijst van de partij (lijststem) of op een kandidaat op die lijst (kandidaatsstem). Doel van dit kiesstelsel is de band tussen kiezer en gekozene versterken. Wel wijst de Raad erop dat als de kandidaatsstem meer gewicht krijgt het belangrijk is de financiering van individuele campagnes te reguleren. Verder worden kanttekeningen geplaatst bij de voorgestelde verhoging van het aantal ondersteuningsverklaringen.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2021

#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies wijziging regeling tijdelijke vervanging leden vertegenwoordigende organen",
#   "foi_publishedDate": "2019-02-11",
#   "dc_description": "In dit advies stemt de Kiesraad in met een regeling waardoor een lid van een vertegenwoordigend orgaan ook tijdelijk vervangen kan worden aan het einde van de zittingsperiode van dat orgaan.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/2/11/advies-wijziging-regeling-tijdelijke-vervanging-leden-vertegenwoordigende-organen",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies over ontwerpregeling vaststelling model proces-verbaal vanwege mogelijke toewijzing extra zetels EP",
#   "foi_publishedDate": "2019-01-14",
#   "dc_description": "De Kiesraad brengt advies uit over een voorgesteld model proces-verbaal in verband met de mogelijke toewijzing van extra zetels voor Nederland in het Europees Parlement bij Brexit. Het nieuwe proces-verbaal vormt een aanvulling op het bestaande proces-verbaal voor de vaststelling van de verkiezingsuitslag van 23 mei 2019 en moet zelfstandig leesbaar zijn, waarvoor enkele aanpassingen worden voorgesteld.",
#   "dc_source": "https://www.kiesraad.nl/adviezen-en-publicaties/adviezen/2019/januari/14/advies-over-ontwerpregeling-vaststelling-model-proces-verbaal-i.v.m.-mogelike-toewijzing-extra-zetels-ep",
#   "dc_publisher": "zb000174",
#   "dc_type": "2e"
# }
#
# Alle JSON-data opgeslagen in Kiesraad_adviesScraper_data1.json

# %%
with open("Kiesraad_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 59

# %%
res2 = []

with open("Kiesraad_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

def retrieveLinksPagina2(driver, urltje):
    resje = {}
    driver.get(urltje)

    # Alle <li> elementen ophalen
    downloads = driver.find_elements(By.CSS_SELECTOR, "div.download a.download-chunk" )
    li_elements = driver.find_elements( By.CSS_SELECTOR, "div.block.docs-pubs.results ul.common li")
    
    for download in downloads:
        # Titel
        title = download.find_element( By.CSS_SELECTOR, "h2" ).text.replace("Download", "").strip().strip("'")
        
        # URL
        url = download.get_attribute("href")
    
        resje[title] = url

    for li in li_elements:
        # Titel
        title = li.find_element(By.CSS_SELECTOR,"h3").text.strip()
        
        # URL
        url = li.find_element(By.CSS_SELECTOR,"a.publication").get_attribute("href")

        resje[title] = url
    
    return resje    

driver = beginSelenium()

for item in data:
    dc_source2 = item.get("dc_source")

    urltjes = retrieveLinksPagina2(driver, dc_source2)

    foi_files = []
    for key, value in urltjes.items():
        if not value:
            continue
        foi_files.append({
            "foi_title": key,
            "foi_source": value,
        })

    res2.append({
        "dc_title": item.get("dc_title"),
        "foi_publishedDate": item.get("foi_publishedDate"),
        "dc_description": item.get("dc_description"),
        "dc_source": dc_source2,
        "dc_publisher": item.get("dc_publisher"),
        "dc_type": item.get("dc_type"),
        "foi_files": foi_files
    })

    time.sleep(5)

driver.quit()

with open("Kiesraad_adviesScraper_data2.json", "w", encoding="utf-8") as f:
    json.dump(res2, f, ensure_ascii=False, indent=2)

print("\nAlle JSON-data opgeslagen in Kiesraad_adviesScraper_data2.json")
# Out:
# Alle JSON-data opgeslagen in Kiesraad_adviesScraper_data2.json

# %%
with open("Kiesraad_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 59
