# %% [markdown]
# # Resultaten Verzameling politieke documenten gerelateerd aan adviezen

# %% [markdown]
# Zoekmethode1 = Handmatig OpenTK
#
# Zoekmethode2 = LLM Thinking
#
# Zoekmethode3 = LLM 5.1 API
#
# Zoekmethode4 = Handmatig Google

# %%
import os
import time
import json

# %%
def geefpublisher(TOOI):
    if TOOI == "zb000174":
        return "Kiesraad", "Kiesraad"
    if TOOI == "oorg10218":
        return "Gezondheidsraad", "GR"
    if TOOI == "oorg10166":
        return "Raad voor het Openbaar Bestuur", "ROB"
    if TOOI == "oorg10261":
        return "Raad voor de leefomgeving en infrastructuur", "Rli"
    if TOOI == "oorg10196":
        return "Commissie voor de milieueffectrapportage", "MER"
    if TOOI == "oorg10252":
        return "Adviescollege Migratie", "AM"

# %%
with open("../data/auto_doc_retrieval_zoekmethode1.json", "r", encoding="utf-8") as f:
    RAW_auto_doc_retrieval_zoekmethode_1 = json.load(f)

with open("../data/auto_doc_retrieval_zoekmethode2.json", "r", encoding="utf-8") as f:
    RAW_auto_doc_retrieval_zoekmethode_2 = json.load(f)

with open("../data/auto_doc_retrieval_zoekmethode3.json", "r", encoding="utf-8") as f:
    RAW_auto_doc_retrieval_zoekmethode_3 = json.load(f)

with open("../data/auto_doc_retrieval_zoekmethode4.json", "r", encoding="utf-8") as f:
    RAW_auto_doc_retrieval_zoekmethode_4 = json.load(f)

####################################################################################
# ID 1

with open("../data/GR_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    GR_adviesScraper_data2 = json.load(f)

ground_truth_id1 = {}

for item in GR_adviesScraper_data2:
    if item.get("dc_title") == "5G en gezondheid":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        bron = item.get("dc_source")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id1[foi_title] = foi_source

# ID 2

with open("../data/GR_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    GR_adviesScraper_data2 = json.load(f)

ground_truth_id2 = {}

for item in GR_adviesScraper_data2:
    if item.get("dc_title") == "Toelaatbaarheid nieuwe vormen van lijkbezorging":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id2[foi_title] = foi_source

# ID 3

with open("../data/Kiesraad_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    Kiesraad_adviesScraper_data2 = json.load(f)

ground_truth_id3 = {}

for item in Kiesraad_adviesScraper_data2:
    if item.get("dc_title") == "Spoedadvies over registratietermijn van kiezers voor het Kiescollege Niet Ingezetenen":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id3[foi_title] = foi_source

# ID 4

with open("../data/MER_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    MER_adviesScraper_data2 = json.load(f)

ground_truth_id4 = {}

for item in MER_adviesScraper_data2:
    if item.get("dc_title") == "3252. CO2-afvanging Twence B.V. te Hengelo":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id4[foi_title] = foi_source

# ID 5

with open("../data/RLI_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    RLI_adviesScraper_data2 = json.load(f)

ground_truth_id5 = {}

for item in RLI_adviesScraper_data2:
    if item.get("dc_title") == "Weg van de wegwerpmaatschappij":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id5[foi_title] = foi_source

# ID 6

with open("../data/RLI_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    RLI_adviesScraper_data2 = json.load(f)

ground_truth_id6 = {}

for item in RLI_adviesScraper_data2:
    if item.get("dc_title") == "Groen uit de crisis":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id6[foi_title] = foi_source

# ID 7 

with open("../data/ROB_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    ROB_adviesScraper_data2 = json.load(f)

ground_truth_id7 = {}

for item in ROB_adviesScraper_data2:
    if item.get("dc_title") == "Adviesrapport Rol nemen, ruimte geven. De rol van het Rijk bij interbestuurlijke samenwerking.":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id7[foi_title] = foi_source

# ID 8

with open("../data/AM_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    AM_adviesScraper_data2 = json.load(f)

ground_truth_id8 = {}

for item in AM_adviesScraper_data2:
    if item.get("dc_title") == "Advies 'Samen werken aan terugkeer'":
        publishedDate = item.get("foi_publishedDate")
        dc_publisher = item.get("dc_publisher")
        publisher = geefpublisher(dc_publisher)
        title = item.get("dc_title")
        for file_id in item.get("foi_files", []):
            foi_title = file_id.get("foi_title")
            foi_source = file_id.get("foi_source")
            ground_truth_id8[foi_title] = foi_source

####################################################################################

# %%
print("######################################## Referentieset")
print(f"Aantal items id 1: {len(ground_truth_id1)}")
print("---------")
print(f"Aantal items id 2: {len(ground_truth_id2)}")
print("---------")
print(f"Aantal items id 3: {len(ground_truth_id3)}")
print("---------")
print(f"Aantal items id 4: {len(ground_truth_id4)}")
print("---------")
print(f"Aantal items id 5: {len(ground_truth_id5)}")
print("---------")
print(f"Aantal items id 6: {len(ground_truth_id6)}")
print("---------")
print(f"Aantal items id 7: {len(ground_truth_id7)}")
print("---------")
print(f"Aantal items id 8: {len(ground_truth_id8)}")
print("---------")
print("######################################## Zoekmethode 1")
print(f"Aantal items id 1: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id1'])}")
print("---------")
print(f"Aantal items id 2: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id2'])}")
print("---------")
print(f"Aantal items id 3: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id3'])}")
print("---------")
print(f"Aantal items id 4: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id4'])}")
print("---------")
print(f"Aantal items id 5: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id5'])}")
print("---------")
print(f"Aantal items id 6: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id6'])}")
print("---------")
print(f"Aantal items id 7: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id7'])}")
print("---------")
print(f"Aantal items id 8: {len(RAW_auto_doc_retrieval_zoekmethode_1['zoekmethode1_id8'])}")
print("---------")
print("######################################## Zoekmethode 2")
print(f"Aantal items id 1: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id1'])}")
print("---------")
print(f"Aantal items id 2: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id2'])}")
print("---------")
print(f"Aantal items id 3: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id3'])}")
print("---------")
print(f"Aantal items id 4: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id4'])}")
print("---------")
print(f"Aantal items id 5: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id5'])}")
print("---------")
print(f"Aantal items id 6: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id6'])}")
print("---------")
print(f"Aantal items id 7: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id7'])}")
print("---------")
print(f"Aantal items id 8: {len(RAW_auto_doc_retrieval_zoekmethode_2['zoekmethode2_id8'])}")
print("---------")
print("######################################## Zoekmethode 3")
print(f"Aantal items id 1: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id1'])}")
print("---------")
print(f"Aantal items id 2: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id2'])}")
print("---------")
print(f"Aantal items id 3: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id3'])}")
print("---------")
print(f"Aantal items id 4: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id4'])}")
print("---------")
print(f"Aantal items id 5: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id5'])}")
print("---------")
print(f"Aantal items id 6: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id6'])}")
print("---------")
print(f"Aantal items id 7: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id7'])}")
print("---------")
print(f"Aantal items id 8: {len(RAW_auto_doc_retrieval_zoekmethode_3['zoekmethode3_id8'])}")
print("---------")
print("######################################## Zoekmethode 4")
print(f"Aantal items id 1: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id1'])}")
print("---------")
print(f"Aantal items id 2: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id2'])}")
print("---------")
print(f"Aantal items id 3: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id3'])}")
print("---------")
print(f"Aantal items id 4: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id4'])}")
print("---------")
print(f"Aantal items id 5: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id5'])}")
print("---------")
print(f"Aantal items id 6: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id6'])}")
print("---------")
print(f"Aantal items id 7: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id7'])}")
print("---------")
print(f"Aantal items id 8: {len(RAW_auto_doc_retrieval_zoekmethode_4['zoekmethode4_id8'])}")
print("---------")
# Out:
# ######################################## Referentieset
# Aantal items id 1: 7
# ---------
# Aantal items id 2: 8
# ---------
# Aantal items id 3: 2
# ---------
# Aantal items id 4: 4
# ---------
# Aantal items id 5: 4
# ---------
# Aantal items id 6: 3
# ---------
# Aantal items id 7: 4
# ---------
# Aantal items id 8: 6
# ---------
# ######################################## Zoekmethode 1
# Aantal items id 1: 37
# ---------
# Aantal items id 2: 19
# ---------
# Aantal items id 3: 1
# ---------
# Aantal items id 4: 1
# ---------
# Aantal items id 5: 31
# ---------
# Aantal items id 6: 16
# ---------
# Aantal items id 7: 20
# ---------
# Aantal items id 8: 11
# ---------
# ######################################## Zoekmethode 2
# Aantal items id 1: 15
# ---------
# Aantal items id 2: 11
# ---------
# Aantal items id 3: 13
# ---------
# Aantal items id 4: 12
# ---------
# Aantal items id 5: 11
# ---------
# Aantal items id 6: 15
# ---------
# Aantal items id 7: 15
# ---------
# ...
