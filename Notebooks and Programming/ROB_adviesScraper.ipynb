# %% [markdown]
# # ROB_AdviesScraper
#
# Doel: ROB adviezen uitgebracht vanaf 2019 tot en met 2024 verzamelen.
#
# Toepassing: Bachelor-scriptie Informatiekunde, Universiteit van Amsterdam
#
# Contact: mitchell.malaihollo@student.uva.nl
#
# Metadata Formatering volgens de [Woogle metadata specificatie](https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema)

# %%
import time
from urllib.parse import urljoin
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from openai import OpenAI
from dotenv import load_dotenv
import json
from selenium.common.exceptions import NoSuchElementException
from urllib.parse import urljoin, urlparse

# %%
HREF_ID_WOORDEN = {"briefadvies", "wetsadvies", "advies", "adviesrapport", "adviesproject"}
ID_WOORDEN = {"briefadvies", "advies:", "advies", "adviesrapport", "adviesproject", "wetsadvies", "adviesvraag"}

USER_AGENT = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) "
    "Gecko/20100101 Firefox/124.0 "
    "AdviescollegeScraper (+mailto:14605120@student.uva.nl; "
    "voor BSc-scriptie Informatiekunde UvA; "
    "doel: informatie inwinnen over verschillende adviescolleges)"
)

BASE_URL = (
    "https://www.raadopenbaarbestuur.nl/documenten?"
    "filters%5B0%5D%5Bfield%5D=publication_date"
    "&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00"
    "&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom"
    "&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00"
    "&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo"
    "&filters%5B0%5D%5Btype%5D=all"
)

BASE = "https://www.raadopenbaarbestuur.nl"

env_path = r"C:\Users\31633\OneDrive\Bureaublad\OpenAI_API_Key.env"  
load_dotenv(env_path)
api_key = os.getenv("OPENAI_API_KEY")
print("Key geladen:", api_key is not None)
# Out:
# Key geladen: True

# %%
import re

def beginSelenium():
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument(f"user-agent={USER_AGENT}")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )
    return driver

def aantalPaginas():
    x = driver.find_element(
        By.CSS_SELECTOR,
        "#main-content > div.search-block > div.search-block__results > nav > ul > li:nth-child(7) > button > span.sr-only"
    )
    y = x.text.strip()
    pagina = re.sub(r"\D", "", y)
    return int(pagina)

driver = beginSelenium()
driver.get(BASE_URL)
time.sleep(2)
aantalPagina = aantalPaginas()
print("Maximaal aantal pagina's om te controleren: " + str(aantalPagina))
print("-----------------------")

adviesURLS = []
for paginaNummer in range(1, aantalPagina + 1):
    if paginaNummer == 1:
        BASE_paginaURL = BASE_URL
    else:
        BASE_paginaURL = f"{BASE_URL}&current=n_{paginaNummer}_n"

    print("Pagina: " + str(paginaNummer))
    print(BASE_paginaURL)

    driver.get(BASE_paginaURL)
    time.sleep(2)

    li_items = driver.find_elements(
        By.CSS_SELECTOR,
        "ul.sui-results-container.links-list li.links-list__item"
    )

    for li in li_items:
        meta_spans = li.find_elements(
            By.CSS_SELECTOR,
            ".meta-data.link-plus__meta-data span"
        )

        # metadata type
        doc_type = meta_spans[0].text.strip().lower()
        a_tag = li.find_element(By.CSS_SELECTOR, "a.link-plus")
        href = a_tag.get_attribute("href")
        if href.startswith("/"):
            href = BASE + href

        # eerste woord van de href
        href_delen = urlparse(href).path
        href_deel = href_delen.strip("/").split("/")[-1]
        eerste_woord = href_deel.split("-")[0]

        # eerste woord van de titel
        title_element = li.find_element(By.CSS_SELECTOR, "h3.link-plus__title")
        title_text = title_element.text.strip().lower()
        eerste_woord_titel = title_text.split()[0]
        
        # metadata check
        if "advies" in doc_type:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue

        # href eerste woord check
        if eerste_woord in HREF_ID_WOORDEN:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue

        # titel check dus Advies:
        if eerste_woord_titel in ID_WOORDEN:
            print(href)
            print("dit is een advies")
            print("-")
            adviesURLS.append(href)
            continue
    time.sleep(5)
    
    print("-------------------")
# Out:
# Maximaal aantal pagina's om te controleren: 17
# -----------------------
# Pagina: 1
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all
# https://www.raadopenbaarbestuur.nl/documenten/2024/11/21/advies-naar-een-uitvoerende-macht
# dit is een advies
# -
# -------------------
# Pagina: 2
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_2_n
# https://www.raadopenbaarbestuur.nl/documenten/2024/10/1/advies-voornemen-tot-overheveling-specifieke-uitkeringen
# dit is een advies
# -
# -------------------
# Pagina: 3
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_3_n
# https://www.raadopenbaarbestuur.nl/documenten/2024/02/29/briefadvies-raamwerk-toekomstbestendige-financiele-verhoudingen
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2024/02/22/briefadvies-onderzoek-eilandelijke-taken-en-middelen-caribisch-nederland
# dit is een advies
# -
# -------------------
# Pagina: 4
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_4_n
# -------------------
# Pagina: 5
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_5_n
# -------------------
# Pagina: 6
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_6_n
# https://www.raadopenbaarbestuur.nl/documenten/2023/03/27/elke-regio-telt-een-nieuwe-aanpak-van-verschillen-tussen-regios
# dit is een advies
# -
# -------------------
# Pagina: 7
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_7_n
# -------------------
# Pagina: 8
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_8_n
# -------------------
# Pagina: 9
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_9_n
# https://www.raadopenbaarbestuur.nl/documenten/2021/11/4/ondersteuning-tweede-kamer
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2021/10/19/briefadvies-herverdeling-gemeentefonds
# dit is een advies
# -
# -------------------
# Pagina: 10
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_10_n
# https://www.raadopenbaarbestuur.nl/documenten/2021/06/24/adviesrapport-droomland-of-niemandsland
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2021/06/02/advies-toepassing-normeringssystematiek
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2021/05/25/advies-sturen-of-gestuurd-worden
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2021/05/11/advies-rol-nemen-ruimte-geven
# dit is een advies
# -
# -------------------
# Pagina: 11
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_11_n
# https://www.raadopenbaarbestuur.nl/documenten/2021/03/11/adviesrapport-rust-reinheid-regelmaat
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2021/02/03/briefadvies-financiele-compensatie-coronacrisis
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2021/01/25/advies-van-parijs-naar-praktijk
# dit is een advies
# -
# -------------------
# Pagina: 12
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_12_n
# https://www.raadopenbaarbestuur.nl/documenten/2020/11/12/adviesrapport-lokale-media-niet-te-missen
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2020/11/05/goede-ondersteuning-sterke-democratie
# dit is een advies
# -
# -------------------
# Pagina: 13
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_13_n
# https://www.raadopenbaarbestuur.nl/documenten/2020/05/01/opcenten-motorrijtuigenbelasting
# dit is een advies
# -
# -------------------
# Pagina: 14
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_14_n
# https://www.raadopenbaarbestuur.nl/documenten/2020/03/12/advies-akkoord-besturen-met-akkoorden-als-evenwichtskunst
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2020/02/13/advies-decentrale-taak-is-politieke-zaak
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2020/01/06/briefadvies-herziening-uitkeringsstelsel
# dit is een advies
# -
# -------------------
# Pagina: 15
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_15_n
# https://www.raadopenbaarbestuur.nl/documenten/2019/09/05/briefadvies-herijking-gemeentefonds
# dit is een advies
# -
# -------------------
# Pagina: 16
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_16_n
# https://www.raadopenbaarbestuur.nl/documenten/2019/09/03/toekomstige-organisatie-en-financiering-lokale-publieke-omroep
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2019/08/12/advies-wetsvoorstel-wet-inburgering-2021
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2019/06/24/jong-geleerd-oud-gedaan
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2019/05/09/zoeken-naar-waarheid
# dit is een advies
# -
# -------------------
# Pagina: 17
# https://www.raadopenbaarbestuur.nl/documenten?filters%5B0%5D%5Bfield%5D=publication_date&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bfrom%5D=2019-01-01T00%3A00%3A00%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B0%5D%5Bname%5D=specificPeriodFrom&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bto%5D=2024-12-31T23%3A59%3A59%2B01%3A00&filters%5B0%5D%5Bvalues%5D%5B1%5D%5Bname%5D=specificPeriodTo&filters%5B0%5D%5Btype%5D=all&current=n_17_n
# https://www.raadopenbaarbestuur.nl/documenten/2019/03/14/advies-beleidsvrijheid-geduid
# dit is een advies
# -
# https://www.raadopenbaarbestuur.nl/documenten/2019/01/10/briefadvies-onderzoeksmethode-verdeelmodellen-sociaal-domein
# dit is een advies
# -
# -------------------

# %%
print("\nAlle unieke adviezen links:")
for link in adviesURLS:
    print(link)

print(f"\nTotaal aantal unieke adviezen-links: {len(adviesURLS)}")
# Out:
# Alle unieke adviezen links:
# https://www.raadopenbaarbestuur.nl/documenten/2024/11/21/advies-naar-een-uitvoerende-macht
# https://www.raadopenbaarbestuur.nl/documenten/2024/10/1/advies-voornemen-tot-overheveling-specifieke-uitkeringen
# https://www.raadopenbaarbestuur.nl/documenten/2024/02/29/briefadvies-raamwerk-toekomstbestendige-financiele-verhoudingen
# https://www.raadopenbaarbestuur.nl/documenten/2024/02/22/briefadvies-onderzoek-eilandelijke-taken-en-middelen-caribisch-nederland
# https://www.raadopenbaarbestuur.nl/documenten/2023/03/27/elke-regio-telt-een-nieuwe-aanpak-van-verschillen-tussen-regios
# https://www.raadopenbaarbestuur.nl/documenten/2021/11/4/ondersteuning-tweede-kamer
# https://www.raadopenbaarbestuur.nl/documenten/2021/10/19/briefadvies-herverdeling-gemeentefonds
# https://www.raadopenbaarbestuur.nl/documenten/2021/06/24/adviesrapport-droomland-of-niemandsland
# https://www.raadopenbaarbestuur.nl/documenten/2021/06/02/advies-toepassing-normeringssystematiek
# https://www.raadopenbaarbestuur.nl/documenten/2021/05/25/advies-sturen-of-gestuurd-worden
# https://www.raadopenbaarbestuur.nl/documenten/2021/05/11/advies-rol-nemen-ruimte-geven
# https://www.raadopenbaarbestuur.nl/documenten/2021/03/11/adviesrapport-rust-reinheid-regelmaat
# https://www.raadopenbaarbestuur.nl/documenten/2021/02/03/briefadvies-financiele-compensatie-coronacrisis
# https://www.raadopenbaarbestuur.nl/documenten/2021/01/25/advies-van-parijs-naar-praktijk
# https://www.raadopenbaarbestuur.nl/documenten/2020/11/12/adviesrapport-lokale-media-niet-te-missen
# https://www.raadopenbaarbestuur.nl/documenten/2020/11/05/goede-ondersteuning-sterke-democratie
# https://www.raadopenbaarbestuur.nl/documenten/2020/05/01/opcenten-motorrijtuigenbelasting
# https://www.raadopenbaarbestuur.nl/documenten/2020/03/12/advies-akkoord-besturen-met-akkoorden-als-evenwichtskunst
# https://www.raadopenbaarbestuur.nl/documenten/2020/02/13/advies-decentrale-taak-is-politieke-zaak
# https://www.raadopenbaarbestuur.nl/documenten/2020/01/06/briefadvies-herziening-uitkeringsstelsel
# https://www.raadopenbaarbestuur.nl/documenten/2019/09/05/briefadvies-herijking-gemeentefonds
# https://www.raadopenbaarbestuur.nl/documenten/2019/09/03/toekomstige-organisatie-en-financiering-lokale-publieke-omroep
# https://www.raadopenbaarbestuur.nl/documenten/2019/08/12/advies-wetsvoorstel-wet-inburgering-2021
# https://www.raadopenbaarbestuur.nl/documenten/2019/06/24/jong-geleerd-oud-gedaan
# https://www.raadopenbaarbestuur.nl/documenten/2019/05/09/zoeken-naar-waarheid
# https://www.raadopenbaarbestuur.nl/documenten/2019/03/14/advies-beleidsvrijheid-geduid
# https://www.raadopenbaarbestuur.nl/documenten/2019/01/10/briefadvies-onderzoeksmethode-verdeelmodellen-sociaal-domein
#
# Totaal aantal unieke adviezen-links: 27

# %%
res = []
for url in adviesURLS:
    client = OpenAI()

    prompt = f"""
    Lees dit document: {url}

    Vul de onderstaande JSON in volgens https://github.com/wooverheid/WoogleDocumentatie/tree/master/SPEC%20MetadataSchema:

    {{
        "dc_title": "",
        "foi_publishedDate": "",
        "dc_description": ""
    }}

    Regels:
    - Alleen écht gevonden info invullen.
    - Max 100 woorden in dc_description.
    - Ontbreekt iets? dan "" laten.
    - datum in jjjj-mm-dd
    - Output = alleen geldige JSON niks anders.
    """
    response = client.responses.create(
        model="gpt-5.1",
        input=prompt,
        tools=[{"type": "web_search"}],
        max_output_tokens=800,
    )
    
    json_str = response.output_text.strip()

    try:
        data = json.loads(json_str)
    except json.JSONDecodeError:
        print("Kon JSON niet parsen voor URL:", url)
        print("Ruwe output was:\n", json_str)
        continue

    data["dc_source"] = url
    data["dc_publisher"] = "oorg10166"
    data["dc_type"] = "2e"
        
    res.append(data)
    
    print(json.dumps(data, ensure_ascii=False, indent=2))
    
    time.sleep(12)

with open("ROB_adviesScraper_data1.json", "w", encoding="utf-8") as f:
    json.dump(res, f, ensure_ascii=False, indent=2)
    
print("\nAlle JSON-data opgeslagen in ROB_adviesScraper_data1.json")
# Out:
# {
#   "dc_title": "Advies 'Naar een uitvoerende macht'",
#   "foi_publishedDate": "2024-11-21",
#   "dc_description": "De Raad voor het Openbaar Bestuur constateert dat er veranderingen nodig zijn in het systeem van het openbaar bestuur om de positie van uitvoerders te versterken. Centrale vragen zijn hoe uitvoerders meer invloed krijgen, hoe kennis en ervaring van professionals centraal kan staan in beleid en wetgeving, en hoe tijdelijke initiatieven kunnen worden omgevormd tot structurele veranderingen in de samenwerking.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2024/11/21/advies-naar-een-uitvoerende-macht",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies 'Voornemen tot overheveling specifieke uitkeringen'",
#   "foi_publishedDate": "2024-10-01",
#   "dc_description": "Het Hoofdlijnenakkoord bevat het voornemen om vrijwel alle specifieke uitkeringen over te hevelen naar het gemeente- en provinciefonds. Dit zou controle- en verantwoordingslasten verminderen en de beleids- en bestedingsvrijheid van decentrale overheden vergroten. De ROB concludeert dat de beoogde besparing van 10% niet is onderbouwd, niet realistisch en niet passend is, omdat verantwoording een democratische waarde is. Daarnaast is overheveling niet altijd wenselijk of mogelijk, vanwege mogelijke ongewenste maatschappelijke gevolgen en herverdeeleffecten.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2024/10/1/advies-voornemen-tot-overheveling-specifieke-uitkeringen",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies: Raamwerk toekomstbestendige financiële verhoudingen",
#   "foi_publishedDate": "2024-02-29",
#   "dc_description": "In dit briefadvies benadrukt de Raad voor het Openbaar Bestuur dat bestuurlijke en financiële verhoudingen tussen overheden uit balans zijn. De raad vraagt aandacht voor fundamentele keuzes per taakgebied, congruentie tussen beleidsvrijheid, bekostiging en risicodeling, herstel van spelregels in de Financiële-verhoudingswet, een sanering van specifieke uitkeringen en het op orde brengen van de bekostiging van medebewindstaken.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2024/02/29/briefadvies-raamwerk-toekomstbestendige-financiele-verhoudingen",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Onderzoek eilandelijke taken en middelen Caribisch Nederland",
#   "foi_publishedDate": "2024-02-22",
#   "dc_description": "De Raad voor het Openbaar Bestuur (ROB) geeft een briefadvies over de herziening van de bestuurlijke en financiële verhoudingen met Caribisch Nederland. De raad constateert dat de voorgestelde aanpassingen in de bekostiging van eilandelijke taken en middelen passen in een patroon van oplossingen binnen een systeem met fundamentele tekortkomingen. Het advies is opgesteld naar aanleiding van een onderzoek van bureau IdeeVersa in opdracht van het ministerie van Binnenlandse Zaken en Koninkrijksrelaties.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2024/02/22/briefadvies-onderzoek-eilandelijke-taken-en-middelen-caribisch-nederland",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies 'Elke regio telt! Een nieuwe aanpak van verschillen tussen regio’s'",
#   "foi_publishedDate": "2023-03-27",
#   "dc_description": "Advies van de Raad voor de leefomgeving en infrastructuur, de Raad voor Volksgezondheid & Samenleving en de Raad voor het Openbaar Bestuur over onwenselijke verschillen in brede welvaart tussen regio’s in Nederland. Het beschrijft regionale achterstanden buiten de economische centrumgebieden en doet aanbevelingen om rijksbeleid te herijken, langjarige programma’s voor regionale ontwikkeling op te zetten en de relatie tussen Rijk en regio’s te versterken zodat brede welvaart in alle regio’s wordt bevorderd.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2023/03/27/elke-regio-telt-een-nieuwe-aanpak-van-verschillen-tussen-regios",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Ondersteuning Tweede Kamer",
#   "foi_publishedDate": "2021-11-04",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over de ondersteuning van de Tweede Kamer.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/11/4/ondersteuning-tweede-kamer",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Herverdeling gemeentefonds",
#   "foi_publishedDate": "2021-10-19",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur op het voorstel voor de nieuwe verdeling van het gemeentefonds.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/10/19/briefadvies-herverdeling-gemeentefonds",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Droomland of niemandsland? Uitgangspunten voor het besturen van regio's",
#   "foi_publishedDate": "2021-06-23",
#   "dc_description": "Regio’s voeren in Nederland veel taken uit, zoals jeugdzorg en milieutoezicht, maar hebben geen formele plek in de bestuurlijke inrichting. De Raad voor het Openbaar Bestuur schetst kansen (de regio als droomland) en knelpunten (democratisch tekort, sectorale indeling, ondoordachte regiovorming) en constateert een groeiende spanning tussen opgaven, verantwoordelijkheden, financiën en legitimiteit. Het rapport formuleert zes uitgangspunten voor het besturen van regio’s en doet drie aanbevelingen om regionale samenwerking te versterken en de discussie over de bestuurlijke inrichting van regio’s vlot te trekken.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/06/24/adviesrapport-droomland-of-niemandsland",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Toepassing Normeringssystematiek",
#   "foi_publishedDate": "2021-06-02",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over de toepassing van de normeringssystematiek voor het gemeente- en provinciefonds. De Raad gaat in op kritiekpunten zoals instabiliteit en beperkte transparantie van de huidige systematiek ‘samen de trap op, samen de trap af’ en doet aanbevelingen voor een stabielere, eenvoudiger en voorspelbare koppeling van de fondsen aan het meerjarig rijksuitgavenkader, inclusief investeringsuitgaven van het Nationaal Groeifonds, en voor monitoring van toereikendheid van middelen voor decentrale overheden.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/06/02/advies-toepassing-normeringssystematiek",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Advies Sturen of gestuurd worden? Over de legitimiteit van sturen met data",
#   "foi_publishedDate": "2021-05-25",
#   "dc_description": "In het advies ‘Sturen of gestuurd worden?’ wijst de Raad voor het Openbaar Bestuur op de noodzaak om de legitimiteit van sturen met data te waarborgen. Hoewel datasturing kansen biedt, kan dit pas succesvol zijn als sturing niet alleen effectief en efficiënt, maar ook legitiem is. Belangrijke thema’s zijn democratische controle op partijen die sturen met data, het tegengaan van machtsmisbruik en corruptie, en het versterken van het leervermogen van het openbaar bestuur.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/05/25/advies-sturen-of-gestuurd-worden",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Rol nemen, ruimte geven. De rol van het Rijk bij interbestuurlijke samenwerking.",
#   "foi_publishedDate": "2021-05-11",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over de rol van het Rijk bij interbestuurlijke samenwerking rond grote opgaven zoals klimaat, wonen, economie en werk. Het rapport beschrijft knelpunten in de samenwerking tussen Rijk en decentrale overheden en doet aanbevelingen, waaronder het aanwijzen van één verantwoordelijke minister per regionale opgave en het hanteren van een model voor gelijkwaardig partnerschap tussen overheden.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/05/11/advies-rol-nemen-ruimte-geven",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Rust-Reinheid-Regelmaat. Evenwicht in de bestuurlijk-financiële verhoudingen",
#   "foi_publishedDate": "2021-03-11",
#   "dc_description": "Het adviesrapport van de Raad voor het Openbaar Bestuur stelt dat de financiën van decentrale overheden piepen en kraken door een disbalans tussen taken, organisatie, bevoegdheden en bekostiging. Hierdoor is er te weinig ruimte voor eigen beleidskeuzes en wordt de slagkracht van gemeenten en andere decentrale overheden beperkt. Het rapport pleit voor herstel van de balans in de bestuurlijk-financiële verhoudingen en roept het kabinet op om fundamentele keuzes te maken.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/03/11/adviesrapport-rust-reinheid-regelmaat",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Financiële compensatie coronacrisis",
#   "foi_publishedDate": "2021-02-03",
#   "dc_description": "Het Rijk en decentrale overheden hebben op constructieve wijze afspraken gemaakt over compensatie van kosten direct gerelateerd aan de coronacrisis. De Raad voor het Openbaar Bestuur beoordeelt onder meer proces, methodiek en definities van de coronacompensatie, niet de hoogte van de bedragen. De Raad acht de pragmatische benadering passend gezien urgentie en uniek karakter van de crisis, maar wijst erop dat structurele en indirecte financiële gevolgen nog onduidelijk zijn en later worden geadresseerd. Ook acht de Raad enige coulance bij verantwoording van de besteding van uitgekeerde compensatie gepast.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/02/03/briefadvies-financiele-compensatie-coronacrisis",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Van Parijs naar praktijk",
#   "foi_publishedDate": "2021-01-25",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over de uitvoeringslasten van het Klimaatakkoord voor gemeenten, provincies en waterschappen. De Raad becijfert dat decentrale overheden de komende drie jaar 1,8 miljard euro nodig hebben en adviseert onder meer een brede doeluitkering, fasering van de bekostiging en betere afstemming tussen lokaal, regionaal en landelijk niveau om de doelen van 49% CO2-reductie in 2030 te halen.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2021/01/25/advies-van-parijs-naar-praktijk",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Lokale media: niet te missen",
#   "foi_publishedDate": "2020-11-12",
#   "dc_description": "Adviesrapport van de Raad voor het Openbaar Bestuur en de Raad voor Cultuur over de positie van lokale en regionale media. De raden concluderen dat lokale media essentieel zijn voor democratie en samenleving, maar hun functies lang niet overal goed kunnen uitvoeren. Zij pleiten voor duidelijke afspraken over bereik en kwaliteit, meer samenwerking tussen omroepen en andere partijen, en een forse versterking van de financiering, onder meer via hogere basisfinanciering en een landelijk dekkend fonds voor lokale en regionale media.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2020/11/12/adviesrapport-lokale-media-niet-te-missen",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Goede ondersteuning, sterke democratie",
#   "foi_publishedDate": "2020-11-05",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur aan de minister van Binnenlandse Zaken en Koninkrijksrelaties over normen voor de ondersteuning van gemeenteraden en provinciale staten. Het rapport gaat onder meer in op de onafhankelijke positie van de griffier, een ondergrens voor rekenkamers, ambtelijke bijstand, fractievergoeding, benodigde middelen en naleving van normen om decentrale volksvertegenwoordigingen beter te ondersteunen.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2020/11/05/goede-ondersteuning-sterke-democratie",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Opcenten Motorrijtuigenbelasting",
#   "foi_publishedDate": "2020-05-01",
#   "dc_description": "Provincies lopen substantiële potentiële inkomsten mis door de (gedeeltelijke) MRB-vrijstelling op (hybride) elektrische voertuigen. De Raad voor het Openbaar Bestuur onderzoekt in hoeverre de inkomsten van provincies wijzigen en of zij hierdoor hun taken nog goed kunnen uitvoeren. Het advies vormt de basis voor overleg tussen Rijk en Interprovinciaal Overleg (IPO) over compensatie voor de derving van opcenten op de motorrijtuigenbelasting.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2020/05/01/opcenten-motorrijtuigenbelasting",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport: Akkoord?! Besturen met akkoorden als evenwichtskunst",
#   "foi_publishedDate": "2020-03-12",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over het sluiten van brede maatschappelijke akkoorden als sturingsinstrument. Het rapport analyseert diverse akkoorden in de context van politieke versnippering en complexe maatschappelijke vraagstukken en formuleert tien aanbevelingen aan het Rijk. De Raad benadrukt het belang van draagvlak, representatie van belanghebbenden, betrokkenheid van het parlement en het vinden van een balans tussen onderhandelen en verbinden, openheid en beslotenheid, vaste afspraken en flexibiliteit, en tussen landelijke afspraken en lokale uitwerking.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2020/03/12/advies-akkoord-besturen-met-akkoorden-als-evenwichtskunst",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Decentrale taak is politieke zaak",
#   "foi_publishedDate": "2020-02-13",
#   "dc_description": "Gemeenteraden benutten hun sturingsruimte in het sociaal domein onvoldoende. Bestuurscultuur en ingrijpen van het Rijk belemmeren dit, terwijl vaak een krachtige lokale visie op zorg en werk ontbreekt. De ROB adviseert alle hoofdrolspelers in de lokale democratie hoe zij de sturende rol van gemeenteraden kunnen versterken, onder meer door in het politieke debat te focussen op maatschappelijke waarden die richting moeten geven aan lokaal sociaal beleid en als meetlat voor controle en evaluatie kunnen dienen.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2020/02/13/advies-decentrale-taak-is-politieke-zaak",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Herziening uitkeringsstelsel",
#   "foi_publishedDate": "2020-01-06",
#   "dc_description": "Het huidige uitkeringsstelsel sluit onvoldoende aan op de verdeling van taken, verantwoordelijkheden en bevoegdheden tussen Rijk en decentrale overheden. De Raad adviseert een eenduidige uitkeringsstructuur met drie uitkeringsvormen: algemene uitkering, decentralisatie-uitkeringen en specifieke uitkeringen. Er worden aanbevelingen gedaan om in de Financiële-verhoudingswet een juridische basis te creëren voor deze uitkeringsvormen, waaronder mogelijkheden voor bekostiging van regionale samenwerking en het systematisch toetsen van specifieke uitkeringen op doelmatigheidsprikkels.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2020/01/06/briefadvies-herziening-uitkeringsstelsel",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Herijking algemene uitkering gemeentefonds",
#   "foi_publishedDate": "2019-09-05",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over de herijking van de algemene uitkering uit het gemeentefonds. De Raad steunt de gekozen aanpak, maar benadrukt het belang van heldere uitgangspunten, zorgvuldig en transparant proces, periodieke beoordeling van beleidsvrijheid en aandacht voor kostenoriëntatie, centrumfuncties en verevening, met name in het sociaal domein.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/09/05/briefadvies-herijking-gemeentefonds",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Toekomstige organisatie en financiering lokale publieke omroepen",
#   "foi_publishedDate": "2019-09-03",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur en de Raad voor Cultuur over de toekomst van de organisatie en financiering van lokale publieke omroepen. Het bespreekt de hoge druk op het huidige stelsel, pleit voor het loslaten van de wettelijke eis om op radio, tv én internet uit te zenden, en doet voorstellen voor directe financiering via de mediabegroting van OCW en stimulering van samenwerking tussen lokale omroepen.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/09/03/toekomstige-organisatie-en-financiering-lokale-publieke-omroep",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies wetsvoorstel Wet inburgering 2021",
#   "foi_publishedDate": "2019-08-12",
#   "dc_description": "De Raad voor het Openbaar Bestuur reageert op het wetsvoorstel voor het nieuwe inburgeringsstelsel. De ROB benadrukt dat het Rijk moet onderbouwen hoeveel geld gemeenten nodig hebben, dat gemeenten voldoende bevoegdheden moeten krijgen om de regierol waar te maken en dat taken en verantwoordelijkheden logischer belegd moeten worden. Ook adviseert de ROB dat alle kosten van de nieuwe taak in onderzoek worden meegenomen en dat gemeenten niet worden afgerekend op prestaties als zij onvoldoende invloed en bevoegdheden hebben.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/08/12/advies-wetsvoorstel-wet-inburgering-2021",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Jong geleerd, oud gedaan",
#   "foi_publishedDate": "2019-06-24",
#   "dc_description": "Adviesrapport van de Raad voor het Openbaar Bestuur over het verhogen van de politieke betrokkenheid van jongeren door experimenten met verlaging van de kiesgerechtigde leeftijd van 18 naar 16 jaar. De ROB adviseert de kiesgerechtigde leeftijd uit de Grondwet te schrappen en de Kieswet aan te passen zodat lokale en provinciale experimenten mogelijk worden, en beveelt daarnaast aan om te investeren in burgerschapsonderwijs en onderzoek naar de effecten van deze verlaging.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/06/24/jong-geleerd-oud-gedaan",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Zoeken naar waarheid",
#   "foi_publishedDate": "2019-05-09",
#   "dc_description": "Advies van de Raad voor het Openbaar Bestuur over waarheidsvinding in de democratie in het digitale tijdperk. Het rapport analyseert kansen en gevaren van digitalisering, met drie digitale beproevingen (desinformatie, desintegratie en despotisme) en vijf strategieën om waarheidsvinding en democratische processen te waarborgen, onder meer via transparantie bij digitale platforms, versterken van kritisch burgerschap en organiseren van tegenmachten.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/05/09/zoeken-naar-waarheid",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Adviesrapport Beleidsvrijheid geduid",
#   "foi_publishedDate": "2019-03-14",
#   "dc_description": "In dit advies werkt de Raad voor het Openbaar Bestuur, op verzoek van de minister van BZK, het begrip beleidsvrijheid voor decentrale overheden nader uit in het kader van de beoogde herziening van de financiële verhoudingen tussen Rijk en gemeenten. Het rapport beschrijft factoren die de mate van beleidsvrijheid bepalen en doet aanbevelingen over onder andere het gemeentefonds, belastinggebied, verdeling van de algemene uitkering en de rol van maatschappelijke acceptatie van verschillen tussen gemeenten.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/03/14/advies-beleidsvrijheid-geduid",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
# {
#   "dc_title": "Briefadvies Onderzoeksmethode verdeelmodellen sociaal domein in het gemeentefonds",
#   "foi_publishedDate": "2019-01-10",
#   "dc_description": "De Raad voor het Openbaar Bestuur adviseert over de onderzoeksmethode voor verdeelmodellen voor het sociaal domein in het gemeentefonds. Omdat problemen in de budgetverdeling niet snel genoeg worden opgelost, stelt de Raad een aanpak langs twee sporen voor: het detecteren en oplossen van de grootste financiële knelpunten op korte termijn en een meerjarig traject naar een toekomstbestendige verdeling, met nadruk op politiek-bestuurlijke keuzes en een goede dataset.",
#   "dc_source": "https://www.raadopenbaarbestuur.nl/documenten/2019/01/10/briefadvies-onderzoeksmethode-verdeelmodellen-sociaal-domein",
#   "dc_publisher": "oorg10166",
#   "dc_type": "2e"
# }
#
# Alle JSON-data opgeslagen in ROB_adviesScraper_data1.json

# %%
with open("ROB_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 27

# %%
res2 = []

with open("ROB_adviesScraper_data1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

def retrieveLinksPagina2(driver, urltje):
    resje = {}
    driver.get(urltje)

    # Alle <li> elementen ophalen
    li_elements = driver.find_elements(By.CSS_SELECTOR, "ul.download-list li.download-list__item")
    li_elements2 = driver.find_elements( By.CSS_SELECTOR, "div#bijlagen ul.links-list li.links-list__item" )
    
    for li in li_elements:
        # Titel
        title = li.find_element(By.CSS_SELECTOR, "span.title").text.strip()
        
        # URL
        url = li.find_element(By.CSS_SELECTOR, "a.download-list__link").get_attribute("href")
    
        resje[title] = url

    for li in li_elements2:
        # Titel
        title = li.find_element( By.CSS_SELECTOR, "span.link-plus__title" ).text.strip()
        
        # URL
        url = li.find_element( By.CSS_SELECTOR, "a.link-plus" ).get_attribute("href")

        resje[title] = url
    
    return resje    

driver = beginSelenium()

for item in data:
    dc_source2 = item.get("dc_source")

    urltjes = retrieveLinksPagina2(driver, dc_source2)

    foi_files = []
    for key, value in urltjes.items():
        if not value:
            continue
        foi_files.append({
            "foi_title": key,
            "foi_source": value,
        })

    res2.append({
        "dc_title": item.get("dc_title"),
        "foi_publishedDate": item.get("foi_publishedDate"),
        "dc_description": item.get("dc_description"),
        "dc_source": dc_source2,
        "dc_publisher": item.get("dc_publisher"),
        "dc_type": item.get("dc_type"),
        "foi_files": foi_files
    })

    time.sleep(5)

driver.quit()

with open("ROB_adviesScraper_data2.json", "w", encoding="utf-8") as f:
    json.dump(res2, f, ensure_ascii=False, indent=2)

print("\nAlle JSON-data opgeslagen in ROB_adviesScraper_data2.json")
# Out:
# Alle JSON-data opgeslagen in ROB_adviesScraper_data2.json

# %%
with open("ROB_adviesScraper_data2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Aantal items in JSON bestand: " + str(len(data)))
# Out:
# Aantal items in JSON bestand: 27
